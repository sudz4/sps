# %%
import pandas as pd

# %% [markdown]
# # data loading / analysis

# %%
# load 'Alternative EV Screen.xlsx'  
alt_ev_screen_df = pd.read_excel('/Users/sudz4/Desktop/SPS_local/sps/x_bio_weapon/Alternative EV Screen.xlsx', sheet_name='Cleaned')


print(len(alt_ev_screen_df))
print(alt_ev_screen_df.columns) 
display(alt_ev_screen_df.head())
# Out:
# 52
# Index(['Ticker', 'Last Price', 'YTD Returns', 'Cover Days', 'SI', 'NT Uptrend',
#        'Intermediate Term Uptrend', '20 DMA', '50 DMA', '100 DMA', '200 DMA',
#        '2Q24', '3Q24', '4Q24', 'ADV $M', 'Cash Runway (Qs)', 'Market Cap',
#        'Total Debt', 'Current', '2Q24 EV', '3Q24 EV', 'Cash on Hand',
#        'Net Loss (Qs)', '20 DMA.1', '50 DMA.1', '100 DMA.1', '200 DMA.1'],
#       dtype='object')
# /Users/sudz4/Desktop/SPS_local/sps/sps_venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /Users/sudz4/Desktop/SPS_local/sps/sps_venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#   Ticker  Last Price  YTD Returns  Cover Days        SI NT Uptrend  \
# 0   PRE       4.7700    -0.192893    1.056601  0.003922  -0.010658
# 1  ANTX       1.1000    -0.946315    1.365465  0.006300  -0.007799
# 2  BOLT       0.6596    -0.411039    1.523604  0.003992  -0.000992
# 3  ALGS       8.7500    -0.472892    1.754932  0.033707  -0.262578
# 4   KZR       0.7651    -0.192421    0.671468  0.017282   0.191504
#
#    Intermediate Term Uptrend    20 DMA    50 DMA   100 DMA  ...  Total Debt  \
# 0                  -0.074336  0.035944  0.024903 -0.089601  ...    2.369388
# 1                  -0.729220  0.041667  0.033543 -0.334483  ...    0.000000
# 2                  -0.282287  0.019971  0.018959 -0.044480  ...   20.219000
# 3                  -0.327272  0.128086 -0.168124 -0.230097  ...   11.138000
# 4                  -0.093192 -0.061710  0.117976  0.164678  ...   18.933000
#
#       Current     2Q24 EV     3Q24 EV Cash on Hand Net Loss (Qs)  20 DMA.1  \
# 0 -124.177628 -112.677628 -101.177628   183.873483       -11.500  4.604495
# 1  -71.713326  -60.213326  -48.713326   104.540000       -11.500     1.056
# 2  -56.729132  -43.277132  -29.825132   102.189000       -13.452  0.646685
# 3  -55.432097  -46.087097  -36.742097    94.536000        -9.345    7.7565
# 4  -89.425605  -66.425605  -43.425605   164.182000       -23.000   0.81542
#
#     50 DMA.1  100 DMA.1  200 DMA.1
# 0   4.654098   5.239461   5.027851
# 1   1.064300   1.652850   3.930500
# 2   0.647327   0.690304   0.901930
# 3  10.518400  11.365075  15.635444
# 4   0.684362   0.656920   0.754693
#
# [5 rows x 27 columns]

# %% [markdown]
# # data mining / validation

# %%
import requests
import pandas as pd
from datetime import datetime
import time

# %%
def get_company_info(cik, headers):
    """
    Get company SIC code and industry info from SEC
    """
    try:
        cik_padded = str(cik).zfill(10)
        url = f'https://data.sec.gov/submissions/CIK{cik_padded}.json'
        
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            return {
                'sic': data.get('sicCode', ''),
                'industry': data.get('sicDescription', ''),
                'ticker': data.get('tickers', [''])[0] if data.get('tickers') else ''
            }
    except Exception as e:
        print(f"Error fetching company info for CIK {cik}: {str(e)}")
    return None

def get_delistings(start_year=2020, save_csv=True):
    """
    Get Form 25 delistings using SEC's HTTPS access
    Returns: DataFrame of delistings
    Optional: Saves CSV file if save_csv=True
    """
    headers = {
        'User-Agent': 'SPS matt@sanspeursystems.com',
        'Accept-Encoding': 'gzip, deflate',
        'Host': 'www.sec.gov'
    }

    all_delistings = []
    current_year = datetime.now().year

    try:
        for year in range(start_year, current_year + 1):
            for quarter in range(1, 5):
                url = f'https://www.sec.gov/Archives/edgar/full-index/{year}/QTR{quarter}/master.idx'
                
                try:
                    print(f"Fetching {year} Q{quarter}...")
                    response = requests.get(url, headers=headers)
                    
                    if response.status_code == 200:
                        lines = response.text.split('\n')
                        data_started = False
                        
                        for line in lines:
                            if data_started:
                                if '|25|' in line:
                                    parts = line.split('|')
                                    if len(parts) >= 4:
                                        cik = parts[0]
                                        # company_info = get_company_info(cik, headers)
                                        
                                        delisting = {
                                            'date': parts[3],
                                            'company': parts[1],
                                            'cik': cik,
                                            'form': '25'
                                            # 'ticker': company_info['ticker'] if company_info else '',
                                            # 'industry': company_info['industry'] if company_info else '',
                                            # 'sic': company_info['sic'] if company_info else ''
                                        }
                                        all_delistings.append(delisting)
                            elif line.startswith('---'):
                                data_started = True
                                
                    time.sleep(0.1)  # SEC rate limiting
                    
                except requests.exceptions.RequestException as e:
                    print(f"Error fetching {year} Q{quarter}: {str(e)}")
                    continue

        if all_delistings:
            df = pd.DataFrame(all_delistings)
            df['date'] = pd.to_datetime(df['date'])
            df = df.sort_values('date', ascending=False)
            
            # Save CSV if requested
            if save_csv:
                csv_filename = f'all_delistings_since_{start_year}.csv'
                df.to_csv(csv_filename, index=False)
                print(f"\nSaved to {csv_filename}")
            
            return df
        else:
            print("No delistings found")
            return None

    except Exception as e:
        print(f"Error: {str(e)}")
        return None

# # Example usage
# if __name__ == "__main__":
#     print("Fetching delistings since 2020...")
    
#     # Get the DataFrame
#     df = get_delistings(2020, save_csv=True)
    
#     if df is not None and not df.empty:
#         print("\nRecent delistings summary:")
#         print(df[['date', 'ticker', 'company', 'industry']].head())
#         print(f"\nTotal delistings found: {len(df)}")

# %%
# execute 
all_delistings_df = get_delistings(2016, save_csv=False)
# Out:
# Fetching 2016 Q1...
# Fetching 2016 Q2...
# Fetching 2016 Q3...
# Fetching 2016 Q4...
# Fetching 2017 Q1...
# Fetching 2017 Q2...
# Fetching 2017 Q3...
# Fetching 2017 Q4...
# Fetching 2018 Q1...
# Fetching 2018 Q2...
# Fetching 2018 Q3...
# Fetching 2018 Q4...
# Fetching 2019 Q1...
# Fetching 2019 Q2...
# Fetching 2019 Q3...
# Fetching 2019 Q4...
# Fetching 2020 Q1...
# Fetching 2020 Q2...
# Fetching 2020 Q3...
# Fetching 2020 Q4...
# Fetching 2021 Q1...
# Fetching 2021 Q2...
# Fetching 2021 Q3...
# Fetching 2021 Q4...
# Fetching 2022 Q1...
# Fetching 2022 Q2...
# Fetching 2022 Q3...
# Fetching 2022 Q4...
# Fetching 2023 Q1...
# Fetching 2023 Q2...
# Fetching 2023 Q3...
# Fetching 2023 Q4...
# Fetching 2024 Q1...
# Fetching 2024 Q2...
# Fetching 2024 Q3...
# Fetching 2024 Q4...

# %%
print(len(all_delistings_df))
display(all_delistings_df.head())
# Out:
# 987
#           date                         company      cik form
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.  1962845   25
# 984 2024-11-04          Onyx Acquisition Co. I  1849548   25
# 977 2024-11-04  NORTHERN LIGHTS FUND TRUST III  1537140   25
# 978 2024-11-04  NORTHERN LIGHTS FUND TRUST III  1537140   25
# 981 2024-10-31  Finch Therapeutics Group, Inc.  1733257   25

# %% [markdown]
# SICK CoDE time

# %%
sick_df = all_delistings_df.copy()

# %%
# make sure CIK is 10 digits
sick_df['cik'] = sick_df['cik'].astype(str).str.zfill(10)
# convert date string to datetime object
sick_df['date'] = pd.to_datetime(sick_df['date'])

# add columns for data extraction preparation
sick_df['ticker'] = ''
sick_df['sic'] = ''
sick_df['sic_description'] = ''
sick_df['is_biotech'] = False
sick_df['biotech_identification_method'] = ''

# %%
print(len(sick_df))
display(sick_df.head())
# Out:
# 987
#           date                         company         cik form ticker sic  \
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.  0001962845   25
# 984 2024-11-04          Onyx Acquisition Co. I  0001849548   25
# 977 2024-11-04  NORTHERN LIGHTS FUND TRUST III  0001537140   25
# 978 2024-11-04  NORTHERN LIGHTS FUND TRUST III  0001537140   25
# 981 2024-10-31  Finch Therapeutics Group, Inc.  0001733257   25
#
#     sic_description  is_biotech biotech_identification_method
# 985                       False
# 984                       False
# 977                       False
# 978                       False
# 981                       False

# %%
# Define biotech-related keywords and patterns (expanded)
biotech_keywords = [
    'therapeutics', 'pharma', 'biotech', 'bio', 'health sciences',
    'medical', 'genetics', 'genomics', 'life sciences', 'biologics',
    'biosciences', 'oncology', 'diagnostic', 'biomedical',
    'laboratory', 'clinical', 'research', 'drug', 'therapeutic',
    'cell therapy', 'gene therapy', 'molecular', 'pharmaceutical'
]

# Define comprehensive biotech and related SIC codes with descriptions
biotech_sic_dict = {
    '2833': 'Medicinal Chemicals and Botanical Products',
    '2834': 'Pharmaceutical Preparations',
    '2835': 'In Vitro and In Vivo Diagnostic Substances',
    '2836': 'Biological Products, Except Diagnostic Substances',
    '3826': 'Laboratory Analytical Instruments',
    '3841': 'Surgical and Medical Instruments',
    '3842': 'Orthopedic, Prosthetic, and Surgical Supplies',
    '3843': 'Dental Equipment and Supplies',
    '3844': 'X-Ray Apparatus and Tubes',
    '3845': 'Electromedical and Electrotherapeutic Apparatus',
    '3851': 'Ophthalmic Goods',
    '8071': 'Medical Laboratories',
    '8731': 'Commercial Physical and Biological Research',
    '8732': 'Commercial Nonphysical Research',
    '8733': 'Noncommercial Research Organizations',
    '8734': 'Testing Laboratories',
    '8999': 'Services, Not Elsewhere Classified (including Medical Research)',
    '6324': 'Hospital and Medical Service Plans',
    '5122': 'Drugs, Proprietaries, and Druggists Sundries'
}

biotech_sic_codes = list(biotech_sic_dict.keys())

# %%
# Set up SEC API request headers
headers = {
    'User-Agent': 'sanspeursystems matt@sanspeursystems.com',
    'Accept-Encoding': 'gzip, deflate',
    'Host': 'data.sec.gov'
}

# Process each company
for idx, row in sick_df.iterrows():
    print(f"Processing {row['company']} ({idx + 1}/{len(sick_df)})")
    
    # Check company name for biotech keywords
    company_name_lower = row['company'].lower()
    matching_keywords = [kw for kw in biotech_keywords if kw in company_name_lower]
    if matching_keywords:
        sick_df.at[idx, 'is_biotech'] = True
        sick_df.at[idx, 'biotech_identification_method'] = f"name_match:{','.join(matching_keywords)}"
    
    # Get SEC data
    cik = row['cik']
    url = f'https://data.sec.gov/submissions/CIK{cik}.json'
    
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            
            # Store basic info
            sick_df.at[idx, 'ticker'] = data.get('tickers', [''])[0]
            sic_code = str(data.get('sic', '')).strip()
            sick_df.at[idx, 'sic'] = sic_code
            sick_df.at[idx, 'sic_description'] = data.get('sicDescription', '') or biotech_sic_dict.get(sic_code, '')
            
            # Check if SIC code matches biotech
            if sic_code in biotech_sic_codes:
                sick_df.at[idx, 'is_biotech'] = True
                current_method = sick_df.at[idx, 'biotech_identification_method']
                if current_method:
                    sick_df.at[idx, 'biotech_identification_method'] = f"{current_method};sic_{sic_code}"
                else:
                    sick_df.at[idx, 'biotech_identification_method'] = f"sic_{sic_code}"
            
            print(f"Company: {row['company']}")
            print(f"SIC: {sic_code} - {sick_df.at[idx, 'sic_description']}")
            print(f"Ticker: {sick_df.at[idx, 'ticker']}")
            print(f"Is Biotech: {sick_df.at[idx, 'is_biotech']}")
            print("---")
            
    except Exception as e:
        print(f"Error for {row['company']}: {str(e)}")
    
    time.sleep(0.1)  # Respect SEC rate limits

# Filter for biotech companies
btech_delisted_df = sick_df[sick_df['is_biotech']].copy()

# Display results
print("\nPotential Biotech Companies Found:")
print(btech_delisted_df[['date', 'company', 'ticker', 'sic', 'sic_description', 'biotech_identification_method']])

# Save results with detailed information
btech_delisted_df.to_csv('biotech_delistings_detailed.csv', index=False)

# Print summary statistics
print("\nSummary Statistics:")
print(f"Total companies processed: {len(sick_df)}")
print(f"Companies identified as biotech: {len(btech_delisted_df)}")
if len(sick_df) > 0:
    print(f"Percentage biotech: {(len(btech_delisted_df) / len(sick_df)) * 100:.1f}%")

# Print identification method breakdown
print("\nIdentification Method Breakdown:")
print(btech_delisted_df['biotech_identification_method'].value_counts())

# Print SIC code distribution for identified biotech companies
print("\nSIC Code Distribution for Identified Biotech Companies:")
sic_distribution = btech_delisted_df['sic'].value_counts()
for sic in sic_distribution.index:
    description = biotech_sic_dict.get(sic, 'Unknown')
    print(f"SIC {sic}: {description} - {sic_distribution[sic]} companies")
# Out:
# Processing PIXIE DUST TECHNOLOGIES, INC. (986/987)
# Company: PIXIE DUST TECHNOLOGIES, INC.
# SIC: 3845 - Electromedical & Electrotherapeutic Apparatus
# Ticker: PXDT
# Is Biotech: True
# ---
# Processing Onyx Acquisition Co. I (985/987)
# Company: Onyx Acquisition Co. I
# Is Biotech: True
# ---
# Processing FIRST BANCSHARES INC /MS/ (954/987)
# Company: FIRST BANCSHARES INC /MS/
# SIC: 6021 - National Commercial Banks
# Ticker: FBMS
# Is Biotech: False
# ---
# Processing TCW ETF Trust (942/987)
# Error for TCW ETF Trust: list index out of range
# Processing TCW ETF Trust (941/987)
# Error for TCW ETF Trust: list index out of range
# Processing KFORCE INC (953/987)
# Company: KFORCE INC
# SIC: 7363 - Services-Help Supply Services
# Ticker: KFRC
# Is Biotech: False
# ---
# Processing MERRIMACK PHARMACEUTICALS INC (932/987)
# Error for MERRIMACK PHARMACEUTICALS INC: list index out of range
# Processing Clever Leaves Holdings Inc. (940/987)
# Error for Clever Leaves Holdings Inc.: list index out of range
# Processing Vaxxinity, Inc. (945/987)
# Company: Vaxxinity, Inc.
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: VAXX
# Is Biotech: True
# ---
# Processing Roth CH Acquisition Co. (947/987)
# Company: Roth CH Acquisition Co.
# SIC: 6770 - Blank Checks
# Ticker: USCTF
# Is Biotech: False
# ---
# Processing TOP SHIPS INC. (933/987)
# Company: TOP SHIPS INC.
# SIC: 4412 - Deep Sea Foreign Transportation of  Freight
# Ticker: TOPS
# Is Biotech: False
# ---
# Processing PECO ENERGY CAPITAL LP (952/987)
# Error for PECO ENERGY CAPITAL LP: list index out of range
# Processing VIA optronics AG (938/987)
# Error for VIA optronics AG: list index out of range
# Processing MERRILL LYNCH DEPOSITOR INC INDEXPLUS TRUST SERIES 2003-1 (931/987)
# Company: MERRILL LYNCH DEPOSITOR INC INDEXPLUS TRUST SERIES 2003-1
# SIC: 6189 - Asset-Backed Securities
# Ticker: IPB
# Is Biotech: False
# ---
# Processing Semantix, Inc. (949/987)
# Error for Semantix, Inc.: list index out of range
# Processing BRAZILIAN DISTRIBUTION CO COMPANHIA BRASILEIRA DE DISTR CBD (929/987)
# Company: BRAZILIAN DISTRIBUTION CO COMPANHIA BRASILEIRA DE DISTR CBD
# SIC: 5411 - Retail-Grocery Stores
# Ticker: CBDBY
# Is Biotech: False
# ---
# Processing Ampio Pharmaceuticals, Inc. (934/987)
# Company: Ampio Pharmaceuticals, Inc.
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: AMPE
# Is Biotech: True
# ---
# Processing Revelstone Capital Acquisition Corp. (948/987)
# Error for Revelstone Capital Acquisition Corp.: list index out of range
# Processing Greenbrook TMS Inc. (935/987)
# Company: Greenbrook TMS Inc.
# SIC: 8090 - Services-Misc Health & Allied Services, NEC
# Ticker: GBNHF
# Is Biotech: False
# ---
# Processing Movella Holdings Inc. (943/987)
# Company: Movella Holdings Inc.
# SIC: 7372 - Services-Prepackaged Software
# Ticker: MVLA
# Is Biotech: False
# ---
# Processing Generation Asia I Acquisition Ltd (921/987)
# Company: Generation Asia I Acquisition Ltd
# SIC: 6770 - Blank Checks
# Ticker: GAQ
# Is Biotech: False
# ---
# Processing Zapata Computing Holdings Inc. (918/987)
# Company: Zapata Computing Holdings Inc.
# SIC: 7372 - Services-Prepackaged Software
# Ticker: ZPTA
# Is Biotech: False
# ---
# Processing ALMADEN MINERALS LTD (892/987)
# Company: ALMADEN MINERALS LTD
# SIC: 1000 - Metal Mining
# Ticker: AAUAF
# Is Biotech: False
# ---
# Processing voxeljet AG (906/987)
# Company: voxeljet AG
# SIC: 3555 - Printing Trades Machinery & Equipment
# Ticker: VJTTY
# Is Biotech: False
# ---
# Processing Atreca, Inc. (903/987)
# Error for Atreca, Inc.: list index out of range
# Processing HCM Acquisition Corp (920/987)
# Error for HCM Acquisition Corp: list index out of range
# Processing Cyteir Therapeutics, Inc. (908/987)
# Error for Cyteir Therapeutics, Inc.: list index out of range
# Processing KELSO TECHNOLOGIES INC (894/987)
# Company: KELSO TECHNOLOGIES INC
# SIC: 3743 - Railroad Equipment
# Ticker: KIQSF
# Is Biotech: False
# ---
# Processing Gryphon Digital Mining, Inc. (910/987)
# Company: Gryphon Digital Mining, Inc.
# SIC: 6199 - Finance Services
# Ticker: GRYP
# Is Biotech: False
# ---
# Processing LianBio (914/987)
# Company: LianBio
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: LIANY
# Is Biotech: True
# ---
# Processing Two Roads Shared Trust (904/987)
# Error for Two Roads Shared Trust: list index out of range
# Processing Science Applications International Corp (905/987)
# Company: Science Applications International Corp
# SIC: 7373 - Services-Computer Integrated Systems Design
# Ticker: SAIC
# Is Biotech: False
# ---
# Processing Vector Acquisition Corp II (917/987)
# Error for Vector Acquisition Corp II: list index out of range
# Processing Vector Acquisition Corp II (916/987)
# Error for Vector Acquisition Corp II: list index out of range
# Processing PHAXIAM Therapeutics S.A. (907/987)
# Error for PHAXIAM Therapeutics S.A.: list index out of range
# Processing Arrow ETF Trust (902/987)
# Error for Arrow ETF Trust: list index out of range
# Processing Tingo Group, Inc. (925/987)
# Company: Tingo Group, Inc.
# SIC: 2000 - Food and Kindred Products
# Ticker: TIOG
# Is Biotech: False
# ---
# Processing ESPORTS ENTERTAINMENT GROUP, INC. (899/987)
# Company: ESPORTS ENTERTAINMENT GROUP, INC.
# SIC: 7900 - Services-Amusement & Recreation Services
# Ticker: GMBL
# Is Biotech: False
# ---
# Processing Cheniere Energy Partners, L.P. (898/987)
# Company: Cheniere Energy Partners, L.P.
# SIC: 4924 - Natural Gas Distribution
# Ticker: CQP
# Is Biotech: False
# ---
# Processing Cheniere Energy, Inc. (922/987)
# Company: Cheniere Energy, Inc.
# SIC: 4924 - Natural Gas Distribution
# Ticker: LNG
# Is Biotech: False
# ---
# Processing Alithya Group inc (909/987)
# Company: Alithya Group inc
# SIC: 7370 - Services-Computer Programming, Data Processing, Etc.
# Ticker: ALYAF
# Is Biotech: False
# ---
# Processing Churchill Capital Corp VII (913/987)
# Error for Churchill Capital Corp VII: list index out of range
# Processing SAFEGUARD SCIENTIFICS INC (926/987)
# Company: SAFEGUARD SCIENTIFICS INC
# SIC: 6799 - Investors, NEC
# Ticker: SFES
# Is Biotech: False
# ---
# Processing Natura &Co Holding S.A. (911/987)
# Error for Natura &Co Holding S.A.: list index out of range
# Processing TuSimple Holdings Inc. (912/987)
# Company: TuSimple Holdings Inc.
# Processing NIAGARA MOHAWK POWER CORP /NY/ (888/987)
# Error for NIAGARA MOHAWK POWER CORP /NY/: list index out of range
# Processing Mynd.ai, Inc. (873/987)
# Company: Mynd.ai, Inc.
# SIC: 3577 - Computer Peripheral Equipment, NEC
# Ticker: MYND
# Is Biotech: False
# ---
# Processing SouthState Corp (890/987)
# Company: SouthState Corp
# SIC: 6022 - State Commercial Banks
# Ticker: SSB
# Is Biotech: False
# ---
# Processing Volato Group, Inc. (883/987)
# Company: Volato Group, Inc.
# SIC: 4522 - Air Transportation, Nonscheduled
# Ticker: SOAR
# Is Biotech: False
# ---
# Processing CITIZENS HOLDING CO /MS/ (857/987)
# Company: CITIZENS HOLDING CO /MS/
# SIC: 6022 - State Commercial Banks
# Ticker: CIZN
# Is Biotech: False
# ---
# Processing SMARTFINANCIAL INC. (856/987)
# Company: SMARTFINANCIAL INC.
# SIC: 6021 - National Commercial Banks
# Ticker: SMBK
# Is Biotech: False
# ---
# Processing AENZA S.A.A. (865/987)
# Error for AENZA S.A.A.: list index out of range
# Processing Listed Funds Trust (871/987)
# Error for Listed Funds Trust: list index out of range
# Processing Kubient, Inc. (876/987)
# Error for Kubient, Inc.: list index out of range
# Processing EA Series Trust (866/987)
# Error for EA Series Trust: list index out of range
# Processing EA Series Trust (867/987)
# Error for EA Series Trust: list index out of range
# Processing EXPEDITORS INTERNATIONAL OF WASHINGTON INC (889/987)
# Company: EXPEDITORS INTERNATIONAL OF WASHINGTON INC
# SIC: 4731 - Arrangement of  Transportation of  Freight & Cargo
# Ticker: EXPD
# Is Biotech: False
# ---
# Processing Virtus ETF Trust II (870/987)
# Error for Virtus ETF Trust II: list index out of range
# Processing EntrepreneurShares Series Trust (863/987)
# Error for EntrepreneurShares Series Trust: list index out of range
# Processing BANCO ITAU CHILE (860/987)
# Error for BANCO ITAU CHILE: list index out of range
# Processing LINDE PLC (872/987)
# Company: LINDE PLC
# SIC: 2810 - Industrial Inorganic Chemicals
# Ticker: LIN
# Is Biotech: False
# ---
# Processing PyroGenesis Canada Inc. (877/987)
# Company: PyroGenesis Canada Inc.
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: PYRGF
# Is Biotech: True
# ---
# Processing OVERSTOCK.COM, INC (858/987)
# Company: OVERSTOCK.COM, INC
# SIC: 5961 - Retail-Catalog & Mail-Order Houses
# Ticker: BYON
# Is Biotech: False
# ---
# Processing PARK CITY GROUP INC (886/987)
# Company: PARK CITY GROUP INC
# SIC: 7374 - Services-Computer Processing & Data Preparation
# Ticker: TRAK
# Is Biotech: False
# ---
# Processing Enthusiast Gaming Holdings Inc. / Canada (884/987)
# Company: Enthusiast Gaming Holdings Inc. / Canada
# SIC: 7900 - Services-Amusement & Recreation Services
# Ticker: EGLXF
# Is Biotech: False
# ---
# Processing Ozon Holdings PLC (879/987)
# Error for Ozon Holdings PLC: list index out of range
# Processing AMERICAN CENTURY ETF TRUST (874/987)
# Error for AMERICAN CENTURY ETF TRUST: list index out of range
# Processing Athena Consumer Acquisition Corp. (885/987)
# Error for Athena Consumer Acquisition Corp.: list index out of range
# Processing Firsthand Technology Value Fund, Inc. (862/987)
# Company: ABB LTD
# SIC: 3613 - Switchgear & Switchboard Apparatus
# Ticker: ABLZF
# Is Biotech: False
# ---
# Processing IDW MEDIA HOLDINGS, INC. (809/987)
# Company: IDW MEDIA HOLDINGS, INC.
# SIC: 7310 - Services-Advertising
# Ticker: IDWM
# Is Biotech: False
# ---
# Processing Vyant Bio, Inc. (805/987)
# Error for Vyant Bio, Inc.: list index out of range
# Processing Insight Acquisition Corp. /DE (824/987)
# Company: Insight Acquisition Corp. /DE
# SIC: 6794 - Patent Owners & Lessors
# Ticker: INAQ
# Is Biotech: False
# ---
# Processing SKYDECK ACQUISITION CORP. (820/987)
# Error for SKYDECK ACQUISITION CORP.: list index out of range
# Processing Orion Biotech Opportunities Corp. (821/987)
# Error for Orion Biotech Opportunities Corp.: list index out of range
# Processing MOTIVATING THE MASSES INC (802/987)
# Error for MOTIVATING THE MASSES INC: list index out of range
# Processing Banco Santander Mexico S.A., Institucion de Banca Multiple, Grupo Financiero Santander Mexico (817/987)
# Error for Banco Santander Mexico S.A., Institucion de Banca Multiple, Grupo Financiero Santander Mexico: list index out of range
# Processing ETF Series Solutions (812/987)
# Error for ETF Series Solutions: list index out of range
# Processing Northern Lights Fund Trust (804/987)
# Error for Northern Lights Fund Trust: list index out of range
# Processing PAN AMERICAN SILVER CORP (825/987)
# Company: PAN AMERICAN SILVER CORP
# SIC: 1040 - Gold and Silver Ores
# Ticker: PAAS
# Is Biotech: False
# ---
# Processing Industrias Bachoco S.A.B. de C.V. (800/987)
# Error for Industrias Bachoco S.A.B. de C.V.: list index out of range
# Processing BlueRiver Acquisition Corp. (819/987)
# Company: BlueRiver Acquisition Corp.
# SIC: 3841 - Surgical & Medical Instruments & Apparatus
# Ticker: BLUAF
# Is Biotech: True
# ---
# Processing Brookfield DTLA Fund Office Trust Investor Inc. (813/987)
# Company: Brookfield DTLA Fund Office Trust Investor Inc.
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: DTLAP
# Is Biotech: False
# ---
# Processing DAVIDsTEA Inc. (814/987)
# Company: DAVIDsTEA Inc.
# SIC: 5400 - Retail-Food Stores
# Ticker: DTEAF
# Is Biotech: False
# ---
# Processing Sio Gene Therapies Inc. (815/987)
# Error for Sio Gene Therapies Inc.: list index out of range
# Processing TITAN MEDICAL INC (828/987)
# Error for TITAN MEDICAL INC: list index out of range
# Processing Primoris Services Corp (807/987)
# Company: Primoris Services Corp
# SIC: 1623 - Water, Sewer, Pipeline, Comm & Power Line Construction
# Ticker: PRIM
# Is Biotech: False
# ---
# Processing Catcha Investment Corp (783/987)
# Error for Catcha Investment Corp: list index out of range
# Processing Rubius Therapeutics, Inc. (774/987)
# Error for Rubius Therapeutics, Inc.: list index out of range
# Processing ObsEva SA (772/987)
# Error for ObsEva SA: list index out of range
# Processing ASPEN GROUP, INC. (770/987)
# Company: ASPEN GROUP, INC.
# SIC: 8200 - Services-Educational Services
# Ticker: ASPU
# Is Biotech: False
# ---
# Processing Listed Funds Trust (771/987)
# Error for Listed Funds Trust: list index out of range
# Processing Loyalty Ventures Inc. (789/987)
# Error for Loyalty Ventures Inc.: list index out of range
# Processing JATT Acquisition Corp (786/987)
# Company: JATT Acquisition Corp
# SIC: 2836 - Biological Products, (No Diagnostic Substances)
# Ticker
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: CMCT
# Is Biotech: False
# ---
# Processing Atlantic Union Bankshares Corp (795/987)
# Company: Atlantic Union Bankshares Corp
# SIC: 6022 - State Commercial Banks
# Ticker: AUB
# Is Biotech: False
# ---
# Processing TATA MOTORS LTD/FI (798/987)
# Error for TATA MOTORS LTD/FI: list index out of range
# Processing CI Financial Corp. (777/987)
# Company: CI Financial Corp.
# SIC: 6282 - Investment Advice
# Ticker: CIXXF
# Is Biotech: False
# ---
# Processing AUTOSCOPE TECHNOLOGIES CORP (799/987)
# Company: AUTOSCOPE TECHNOLOGIES CORP
# SIC: 3829 - Measuring & Controlling Devices, NEC
# Ticker: AATC
# Is Biotech: False
# ---
# Processing Eagle Bulk Shipping Inc. (769/987)
# Error for Eagle Bulk Shipping Inc.: list index out of range
# Processing TUESDAY MORNING CORP/DE (794/987)
# Company: TUESDAY MORNING CORP/DE
# SIC: 5331 - Retail-Variety Stores
# Ticker: TUEMQ
# Is Biotech: False
# ---
# Processing PS BUSINESS PARKS, INC./MD (793/987)
# Error for PS BUSINESS PARKS, INC./MD: list index out of range
# Processing Direxion Shares ETF Trust (729/987)
# Error for Direxion Shares ETF Trust: list index out of range
# Processing Evergy, Inc. (746/987)
# Company: Evergy, Inc.
# SIC: 4931 - Electric & Other Services Combined
# Ticker: EVRG
# Is Biotech: False
# ---
# Processing EA Series Trust (737/987)
# Error for EA Series Trust: list index out of range
# Processing EA Series Trust (738/987)
# Error for EA Series Trust: list index out of range
# Processing Listed Funds Trust (742/987)
# Error for Listed Funds Trust: list index out of range
# Processing Listed Funds Trust (743/987)
# Error for Listed Funds Trust: list index out of range
# Processing Harbor ETF Trust (758/987)
# Error for Harbor ETF Trust: list index out of range
# Processing Social Leverage Acquisition Corp I (755/987)
# Error for Social Leverage Acquisition Corp I: list index out of range
# Processing Drive Shack Inc. (726/987)
# Company: Drive Shack Inc.
# SIC: 5810 - Retail-Eating & Drinking Places
# Ticker: DSHK
# Is Biotech: False
# ---
# Processing Rubicon Technology, Inc. (727/987)
# Company: Rubicon Technology, Inc.
# SIC: 3674 - Semiconductors & Related Devices
# Ticker: RBCN
# Is Biotech: False
# ---
# Processing Hoegh LNG Partners LP (740/987)
# Company: Hoegh LNG Partners LP
# SIC: 4400 - Water Transportation
# Ticker: HMLPF
# Is Biotech: False
# ---
# Processing Quotient Ltd (739/987)
# Error for Quotient Ltd: list index out of range
# Processing Ever-Glory International Group, Inc. (763/987)
# Error for Ever-Glory International Group, Inc.: list index out of range
# Processing TWILIO INC (730/987)
# Company: TWILIO INC
# SIC: 7372 - Services-Prepackaged Software
# Ticker: TWLO
# Is Biotech: False
# ---
# Processing NORTHERN LIGHTS FUND TRUST II (733/987)
# Error for NORTHERN LIGHTS FUND TRUST II: list index out of range
# Processing AMERCO /NV/ (760/987)
# Company: AMERCO /NV/
# SIC: 7510 - Services-Auto Rental & Leasing (No Drivers)
# Ticker: UHAL
# Is Biotech: False
# ---
# Processing CCC Intelligent Solutions Holdings Inc. (752/987)
# Company: CCC Intelligent Solutions Holdings Inc.
# SIC: 7372 - Services-Prepackaged Software
# Ticker: CCCS
# Is Biotech: False
# ---
# Processing Zymeworks Inc. (759/987)
# Company: Zymeworks Inc.
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: ZYME
# Is Biotech: True
# ---
# Processing Live Oak Bancshares, Inc. (732/987)
# Company: Live Oak Bancshares, Inc.
# SIC: 6022 - State Commercial Banks
# Ticker: LOB
# Is Biotech: False
# ---
# Processing Horizon Acquisition Corp II (753/987)
# Error for Horizon Acquisition Corp II: list index out of range
# Processing Venus Acquisition Corp (747/987)
# Company: Venus Acquisition Corp
# SIC: 7371 - Services-Computer Programming Services
# Ticker: MLGO
# Is Biotech: False
# ---
# Processing AMERICA FIRST MULTIFAMILY INVESTORS, L.P. (724/987)
# Company: AMERICA FIRST MULTIFAMILY INVESTORS, L.P.
# SIC: 6199 - Finance Services
# Ticker: GHI
# Is Biotech: False
# ---
# Processing ETF Series Solutions (734/987)
# Error for ETF Series Solutions: list index out of range
# Processing Exchange Listed Funds Trust (736/987)
# Error for Exchange Listed Funds Trust: list index out of range
# Processing First Light Acquisition Group, Inc. (757/987)
# Company: First Light Acquisition Group, Inc.
# SIC: 2836 - Biological Products, (No Diagnostic Substances)
# Ticker: CLDI
# Is Biotech: True
# ---
# Processing 8X8 INC /DE/ (723/987)
# Company: 8X8 INC /DE/
# SIC: 7374 - Services-Computer Processing & Data Preparation
# Ticker: EGHT
# Is Biotech: False
# ---
# Processing HPX Corp. (749/987)
# Error for HPX Corp.: list index out of range
# Processing FedNat Holding Co (725/987)
# Error for FedNat Holding Co: list index out of range
# Processing PIMCO ETF Trust (731/987)
# Error for PIMCO ETF Trust: list index out of range
# Processing WisdomTree Investments, Inc. (762/987)
# Company: WisdomTree Investments, Inc.
# SIC: 6211 - Security Brokers, Dealers & Flotation Companies
# Ticker: WT
# Is Biotech: False
# ---
# Processing Sierra Metals Inc. (745/987)
# Company: Sierra Metals Inc.
# SIC: 1000 - Metal Mining
# Ticker: SMTSF
# Is Biotech: False
# ---
# Processing Pacer Funds Trust (741/987)
# Error for Pacer Funds Trust: list index out of range
# Processing Victory Portfolios II (735/987)
# Error for Victory Portfolios II: list index out of range
# Processing BOA Acquisition Corp. (756/987)
# Error for BOA Acquisition Corp.: list index out of range
# Processing SAFEGUARD SCIENTIFICS INC (761/987)
# Company: SAFEGUARD SCIENTIFICS INC
# SIC: 6799 - Investors, NEC
# Ticker: SFES
# Is Biotech: False
# ---
# Processing Kinetik Holdings Inc. (744/987)
# Company: Kinetik Holdings Inc.
# SIC: 4922 - Natural Gas Transmission
# Ticker: KNTK
# Is Biotech: False
# ---
# Processing Tailwind Acquisition Corp. (751/987)
# Company: Tailwind Acquisition Corp.
# SIC: 3690 - Miscellaneous Electrical Machinery, Equipment & Supplies
# ---
# Processing GUINNESS ATKINSON FUNDS (645/987)
# Error for GUINNESS ATKINSON FUNDS: list index out of range
# Processing CONDOR HOSPITALITY TRUST, INC. (646/987)
# Error for CONDOR HOSPITALITY TRUST, INC.: list index out of range
# Processing GLACIER BANCORP, INC. (643/987)
# Company: GLACIER BANCORP, INC.
# SIC: 6022 - State Commercial Banks
# Ticker: GBCI
# Is Biotech: False
# ---
# Processing MAXLINEAR INC (612/987)
# Company: MAXLINEAR INC
# SIC: 3674 - Semiconductors & Related Devices
# Ticker: MXL
# Is Biotech: False
# ---
# Processing Green Brick Partners, Inc. (616/987)
# Company: Green Brick Partners, Inc.
# SIC: 1531 - Operative Builders
# Ticker: GRBK
# Is Biotech: False
# ---
# Processing Boxed, Inc. (635/987)
# Error for Boxed, Inc.: list index out of range
# Processing TPG Pace Solutions Corp. (638/987)
# Error for TPG Pace Solutions Corp.: list index out of range
# Processing BigBear.ai Holdings, Inc. (637/987)
# Company: BigBear.ai Holdings, Inc.
# SIC: 7372 - Services-Prepackaged Software
# Ticker: BBAI
# Is Biotech: False
# ---
# Processing GARMIN LTD (610/987)
# Company: GARMIN LTD
# SIC: 3812 - Search, Detection, Navigation, Guidance, Aeronautical Sys
# Ticker: GRMN
# Is Biotech: False
# ---
# Processing Baker Hughes Co (625/987)
# Company: Baker Hughes Co
# SIC: 3533 - Oil & Gas Field Machinery & Equipment
# Ticker: BKR
# Is Biotech: False
# ---
# Processing Yunhong International (628/987)
# Error for Yunhong International: list index out of range
# Processing Baker Hughes Holdings LLC (642/987)
# Error for Baker Hughes Holdings LLC: list index out of range
# Processing Annovis Bio, Inc. (617/987)
# Company: Annovis Bio, Inc.
# ...
# Processing Cambria ETF Trust (92/987)
# Error for Cambria ETF Trust: list index out of range
# Processing China Lending Corp (96/987)
# Company: China Lending Corp
# SIC: 6159 - Miscellaneous Business Credit Institution
# Ticker: RAHGF
# Is Biotech: False
# ---
# Processing Parnell Pharmaceuticals Holdings Ltd (95/987)
# Error for Parnell Pharmaceuticals Holdings Ltd: list index out of range
# Processing NORTHWEST BIOTHERAPEUTICS INC (75/987)
# Company: NORTHWEST BIOTHERAPEUTICS INC
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: NWBO
# Is Biotech: True
# ---
# Processing IMPERVA INC (88/987)
# Error for IMPERVA INC: list index out of range
# Processing AMERICA MOVIL SAB DE CV/ (77/987)
# Company: AMERICA MOVIL SAB DE CV/
# SIC: 4813 - Telephone Communications (No Radiotelephone)
# Ticker: AMX
# Is Biotech: False
# ---
# Processing AVIVA PLC (79/987)
# Error for AVIVA PLC: list index out of range
# Processing CIPHER PHARMACEUTICALS INC (86/987)
# Error for CIPHER PHARMACEUTICALS INC: list index out of range
# Processing PowerShares Exchange-Traded Fund Trust II (89/987)
# Error for PowerShares Exchange-Traded Fund Trust II: list index out of range
# Processing POWERSHARES EXCHANGE TRADED FUND TRUST (83/987)
# Error for POWERSHARES EXCHANGE TRADED FUND TRUST: list index out of range
# Processing P10 Industries, Inc. (71/987)
# Error for P10 Industries, Inc.: list index out of range
# Processing CREDIT SUISSE AG (73/987)
# Company: CREDIT SUISSE AG
# SIC: 6211 - Security Brokers, Dealers & Flotation Companies
# Ticker: GLDI
# Is Biotech: False
# ---
# Processing AG&E HOLDINGS INC. (74/987)
# Error for AG&E HOLDINGS INC.: list index out of range
# Processing CREDIT SUISSE AG (72/987)
# Company: CREDIT SUISSE AG
# SIC: 6211 - Security Brokers, Dealers & Flotation Companies
# Ticker: GLDI
# Is Biotech: False
# ---
# Processing TETRALOGIC PHARMACEUTICALS CORP (87/987)
# Error for TETRALOGIC PHARMACEUTICALS CORP: list index out of range
# Processing CubeSmart (84/987)
# Company: CubeSmart
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: CUBE
# Is Biotech: False
# ---
# Processing AVG Technologies N.V. (91/987)
# Error for AVG Technologies N.V.: list index out of range
# Processing MEDGENICS, INC. (78/987)
# Error for MEDGENICS, INC.: list index out of range
# Processing ETFis Series Trust I (93/987)
# Error for ETFis Series Trust I: list index out of range
# Processing TOFUTTI BRANDS INC (97/987)
# Company: TOFUTTI BRANDS INC
# SIC: 2024 - Ice Cream & Frozen Desserts
# Ticker: TOFB
# Is Biotech: False
# ---
# Processing Highland Funds I (56/987)
# Error for Highland Funds I: list index out of range
# Processing Cogint, Inc. (61/987)
# Company: Cogint, Inc.
# SIC: 7310 - Services-Advertising
# Ticker: FLNT
# Is Biotech: False
# ---
# Processing FXCM Inc. (63/987)
# Error for FXCM Inc.: list index out of range
# Processing Glori Energy Inc. (64/987)
# Error for Glori Energy Inc.: list index out of range
# Processing FIRSTCASH, INC (68/987)
# Company: FIRSTCASH, INC
# SIC: 5900 - Retail-Miscellaneous Retail
# Ticker: FCFS
# Is Biotech: False
# ---
# Processing NUVEEN MISSOURI PREMIUM INCOME MUNICIPAL FUND (70/987)
# Company: NUVEEN MISSOURI PREMIUM INCOME MUNICIPAL FUND
# SIC:  -
# Ticker: NOM
# Is Biotech: False
# ---
# Processing NUVEEN MUNICIPAL HIGH INCOME OPPORTUNITY FUND (53/987)
# Company: NUVEEN MUNICIPAL HIGH INCOME OPPORTUNITY FUND
# SIC:  -
# Ticker: NMZ
# Is Biotech: False
# ---
# Processing NUVEEN REAL ESTATE INCOME FUND (51/987)
# Company: NUVEEN REAL ESTATE INCOME FUND
# SIC:  -
# Ticker: JRS
# Is Biotech: False
# ---
# Processing Nuveen California Municipal Value Fund 2 (59/987)
# Error for Nuveen California Municipal Value Fund 2: list index out of range
# Processing Nuveen New York Municipal Value Fund 2 (60/987)
# Error for Nuveen New York Municipal Value Fund 2: list index out of range
# Processing RR Donnelley & Sons Co (66/987)
# Error for RR Donnelley & Sons Co: list index out of range
# Processing ORGANOVO HOLDINGS, INC. (62/987)
# Company: ORGANOVO HOLDINGS, INC.
# SIC: 2836 - Biological Products, (No Diagnostic Substances)
# Ticker: ONVO
# Is Biotech: True
# ---
# Processing DXI Energy Inc. (55/987)
# Error for DXI Energy Inc.: list index out of range
# Processing Armco Metals Holdings, Inc. (58/987)
# Error for Armco Metals Holdings, Inc.: list index out of range
# Processing WILSHIRE BANCORP INC (54/987)
# Error for WILSHIRE BANCORP INC: list index out of range
# Processing CLECO POWER LLC (65/987)
# Error for CLECO POWER LLC: list index out of range
# Processing SPECTRUM MANAGEMENT HOLDING COMPANY, LLC (57/987)
# Error for SPECTRUM MANAGEMENT HOLDING COMPANY, LLC: list index out of range
# Processing GLOBEIMMUNE INC (52/987)
# Error for GLOBEIMMUNE INC: list index out of range
# Processing OVERSEAS SHIPHOLDING GROUP INC (67/987)
# Error for OVERSEAS SHIPHOLDING GROUP INC: list index out of range
# Processing ICA CORP (69/987)
# Error for ICA CORP: list index out of range
# Processing TRAVELCENTERS OF AMERICA LLC (36/987)
# Error for TRAVELCENTERS OF AMERICA LLC: list index out of range
# Processing TRAVELCENTERS OF AMERICA LLC (35/987)
# Error for TRAVELCENTERS OF AMERICA LLC: list index out of range
# Processing TRAVELCENTERS OF AMERICA LLC (34/987)
# Error for TRAVELCENTERS OF AMERICA LLC: list index out of range
# Processing TRAVELCENTERS OF AMERICA LLC (33/987)
# Error for TRAVELCENTERS OF AMERICA LLC: list index out of range
# Processing SENIOR HOUSING PROPERTIES TRUST (21/987)
# Company: SENIOR HOUSING PROPERTIES TRUST
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: DHC
# Is Biotech: False
# ---
# Processing SENIOR HOUSING PROPERTIES TRUST (19/987)
# Company: SENIOR HOUSING PROPERTIES TRUST
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: DHC
# Is Biotech: False
# ---
# Processing FIVE STAR QUALITY CARE INC (29/987)
# Error for FIVE STAR QUALITY CARE INC: list index out of range
# Processing SENIOR HOUSING PROPERTIES TRUST (20/987)
# Company: SENIOR HOUSING PROPERTIES TRUST
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: DHC
# Is Biotech: False
# ---
# Processing Government Properties Income Trust (40/987)
# Company: Government Properties Income Trust
# SIC: 6500 - Real Estate
# Ticker: OPI
# Is Biotech: False
# ---
# Processing Government Properties Income Trust (39/987)
# Company: Government Properties Income Trust
# SIC: 6500 - Real Estate
# Ticker: OPI
# Is Biotech: False
# ---
# Processing Select Income REIT (42/987)
# Error for Select Income REIT: list index out of range
# Processing HOSPITALITY PROPERTIES TRUST (49/987)
# Company: HOSPITALITY PROPERTIES TRUST
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: SVC
# Is Biotech: False
# ---
# Processing HOSPITALITY PROPERTIES TRUST (50/987)
# Company: HOSPITALITY PROPERTIES TRUST
# SIC: 6798 - Real Estate Investment Trusts
# Ticker: SVC
# Is Biotech: False
# ---
# Processing PHOENIX COMPANIES INC/DE (25/987)
# Error for PHOENIX COMPANIES INC/DE: list index out of range
# Processing Opko Health, Inc. (48/987)
# Company: Opko Health, Inc.
# SIC: 2834 - Pharmaceutical Preparations
# Ticker: OPK
# Is Biotech: True
# ---
# Processing Tribune Publishing Co (44/987)
# Error for Tribune Publishing Co: list index out of range
# Processing TRUPANION INC. (32/987)
# Company: TRUPANION INC.
# SIC: 6324 - Hospital & Medical Service Plans
# Ticker: TRUP
# Is Biotech: True
# ---
# Processing Paragon Shipping Inc. (38/987)
# Error for Paragon Shipping Inc.: list index out of range
# Error for Axion Power International, Inc.: list index out of range
# Processing ITERIS, INC. (13/987)
# Company: ITERIS, INC.
# SIC: 3669 - Communications Equipment, NEC
# Ticker: ITI
# Is Biotech: False
# ---
# Processing Timberline Resources Corp (5/987)
# Error for Timberline Resources Corp: list index out of range
# Processing QC Holdings, Inc. (6/987)
# Error for QC Holdings, Inc.: list index out of range
# Processing iSHARES INC (16/987)
# Error for iSHARES INC: list index out of range
# Processing iSHARES TRUST (2/987)
# Error for iSHARES TRUST: list index out of range
# Processing TASMAN METALS LTD. (12/987)
# Error for TASMAN METALS LTD.: list index out of range
# Processing MARKET VECTORS ETF TRUST (3/987)
# Error for MARKET VECTORS ETF TRUST: list index out of range
# Processing WILLIS GROUP HOLDINGS PLC (4/987)
# Company: WILLIS GROUP HOLDINGS PLC
# SIC: 6411 - Insurance Agents, Brokers & Service
# Ticker: WTW
# Is Biotech: False
# ---
#
# Potential Biotech Companies Found:
#           date                         company ticker   sic  \
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.   PXDT  3845
# 981 2024-10-31  Finch Therapeutics Group, Inc.   FNCH  2836
# 980 2024-10-11  Guardion Health Sciences, Inc.   GHSI  2834
# 982 2024-10-07                   Renalytix plc  RNLXY  8071
# 967 2024-09-20                Telesis Bio Inc.   TBIO  3826
# ..         ...                             ...    ...   ...
# 61  2016-08-05         ORGANOVO HOLDINGS, INC.   ONVO  2836
# 47  2016-06-23               Opko Health, Inc.    OPK  2834
# 31  2016-06-16                  TRUPANION INC.   TRUP  6324
# 42  2016-06-02          Biotie Therapies Corp.
# 16  2016-02-17                     MASIMO CORP   MASI  3845
#
#                                      sic_description  \
# 985    Electromedical & Electrotherapeutic Apparatus
# 981  Biological Products, (No Diagnostic Substances)
# 980                      Pharmaceutical Preparations
# 982                    Services-Medical Laboratories
# 967                Laboratory Analytical Instruments
# ..                                               ...
# 61   Biological Products, (No Diagnostic Substances)
# 47                       Pharmaceutical Preparations
# 31                  Hospital & Medical Service Plans
# 42
# 16     Electromedical & Electrotherapeutic Apparatus
#
#                     biotech_identification_method
# 985                                      sic_3845
# 981  name_match:therapeutics,therapeutic;sic_2836
# 980           name_match:health sciences;sic_2834
# 982                                      sic_8071
# 967                       name_match:bio;sic_3826
# ..                                            ...
# 61                                       sic_2836
# 47                                       sic_2834
# 31                                       sic_6324
# 42                                 name_match:bio
# 16                                       sic_3845
#
# [87 rows x 6 columns]
#
# Summary Statistics:
# Total companies processed: 987
# Companies identified as biotech: 87
# Percentage biotech: 8.8%
#
# Identification Method Breakdown:
# biotech_identification_method
# sic_2834                                            14
# sic_2836                                             8
# name_match:bio                                       7
# name_match:pharma,pharmaceutical                     7
# sic_3841                                             4
# name_match:therapeutics,therapeutic                  4
# sic_3845                                             3
# name_match:pharma,pharmaceutical;sic_2834            3
# name_match:bio;sic_2834                              3
# name_match:pharma,bio                                3
# name_match:therapeutics,therapeutic;sic_2834         2
# name_match:medical                                   2
# sic_8731                                             2
# sic_6324                                             2
# name_match:medical;sic_3841                          2
# sic_2833                                             2
# name_match:oncology                                  1
# name_match:biotech,bio;sic_2834                      1
# sic_3826                                             1
# name_match:genetics                                  1
# name_match:pharma,bio,pharmaceutical;sic_2834        1
# name_match:life sciences                             1
# sic_2835                                             1
# name_match:bio,biosciences;sic_2836                  1
# name_match:bio,biologics;sic_2834                    1
# name_match:bio;sic_3826                              1
# name_match:bio,biosciences                           1
# name_match:medical;sic_3845                          1
# name_match:pharma                                    1
# name_match:therapeutics,therapeutic;sic_2836         1
# name_match:health sciences;sic_2834                  1
# name_match:biotech,bio                               1
# sic_8071                                             1
# sic_3851                                             1
# name_match:therapeutics,bio,therapeutic;sic_2834     1
# Name: count, dtype: int64
#
# SIC Code Distribution for Identified Biotech Companies:
# SIC 2834: Pharmaceutical Preparations - 27 companies
# SIC : Unknown - 27 companies
# SIC 2836: Biological Products, Except Diagnostic Substances - 10 companies
# SIC 3841: Surgical and Medical Instruments - 6 companies
# SIC 3845: Electromedical and Electrotherapeutic Apparatus - 4 companies
# SIC 3826: Laboratory Analytical Instruments - 2 companies
# SIC 8731: Commercial Physical and Biological Research - 2 companies
# SIC 2833: Medicinal Chemicals and Botanical Products - 2 companies
# SIC 6324: Hospital and Medical Service Plans - 2 companies
# SIC 8071: Medical Laboratories - 1 companies
# SIC 8000: Unknown - 1 companies
# SIC 3851: Ophthalmic Goods - 1 companies
# SIC 2870: Unknown - 1 companies
# SIC 2835: In Vitro and In Vivo Diagnostic Substances - 1 companies

# %%
print(len(btech_delisted_df))   
display(btech_delisted_df.head())
# Out:
# 87
#           date                         company         cik form ticker   sic  \
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.  0001962845   25   PXDT  3845
# 981 2024-10-31  Finch Therapeutics Group, Inc.  0001733257   25   FNCH  2836
# 980 2024-10-11  Guardion Health Sciences, Inc.  0001642375   25   GHSI  2834
# 982 2024-10-07                   Renalytix plc  0001811115   25  RNLXY  8071
# 967 2024-09-20                Telesis Bio Inc.  0001850079   25   TBIO  3826
#
#                                      sic_description  is_biotech  \
# 985    Electromedical & Electrotherapeutic Apparatus        True
# 981  Biological Products, (No Diagnostic Substances)        True
# 980                      Pharmaceutical Preparations        True
# 982                    Services-Medical Laboratories        True
# 967                Laboratory Analytical Instruments        True
#
#                     biotech_identification_method
# 985                                      sic_3845
# 981  name_match:therapeutics,therapeutic;sic_2836
# 980           name_match:health sciences;sic_2834
# 982                                      sic_8071
# 967                       name_match:bio;sic_3826

# %%
# print stocks with no ticker
print(len(btech_delisted_df[btech_delisted_df['ticker'] == '']))
# Out:
# 27

# %%
# drop rows with no ticker
print(len(btech_delisted_df))
btech_delisted_df = btech_delisted_df[btech_delisted_df['ticker'] != '']
print(len(btech_delisted_df))
# Out:
# 87
# 60

# %%
# # take a look at the data
# display(btech_delisted_df)

# %%
from datetime import timedelta

# %%
#### ----
# add SEC delisting reasons data to df
#### ----
def add_sec_delisting_reasons(df):
    """
    Add SEC-based delisting reasons to existing biotech dataframe
    """
    # Add new columns for SEC information
    df['delisting_reason'] = ''
    df['sec_filings'] = ''
    
    # Set up SEC API headers
    headers = {
        'User-Agent': 'sanspeursystems matt@sanspeursystems.com',  
        'Accept-Encoding': 'gzip, deflate',
        'Host': 'data.sec.gov'
    }
    
    for idx, row in df.iterrows():
        print(f"Processing {row['ticker']} ({idx + 1}/{len(df)})")
        
        cik = str(row['cik']).zfill(10)  # Pad CIK with leading zeros
        delisting_date = pd.to_datetime(row['date'])
        start_date = delisting_date - timedelta(days=90)  # Look back 90 days
        
        try:
            # Get SEC filings
            url = f'https://data.sec.gov/submissions/CIK{cik}.json'
            response = requests.get(url, headers=headers)
            
            if response.status_code == 200:
                data = response.json()
                recent_filings = data.get('filings', {}).get('recent', {})
                
                if recent_filings:
                    forms = recent_filings.get('form', [])
                    dates = recent_filings.get('filingDate', [])
                    
                    relevant_filings = []
                    primary_reason = 'Unknown'
                    
                    # Check filings around delisting date
                    for form, file_date in zip(forms, dates):
                        file_date = pd.to_datetime(file_date)
                        
                        if start_date <= file_date <= delisting_date:
                            if form == '25':
                                primary_reason = 'Voluntary Delisting'
                                relevant_filings.append(f'Form 25 ({file_date.date()})')
                                
                            elif form in ['DEFM14A', 'PREM14A']:
                                primary_reason = 'Merger/Acquisition'
                                relevant_filings.append(f'Merger Proxy {form} ({file_date.date()})')
                                
                            elif form == '15':
                                if primary_reason == 'Unknown':
                                    primary_reason = 'Deregistration'
                                relevant_filings.append(f'Form 15 ({file_date.date()})')
                                
                            elif any(x in form for x in ['15-12B', '15-12G']):
                                primary_reason = 'Bankruptcy/Liquidation'
                                relevant_filings.append(f'{form} ({file_date.date()})')
                            
                            elif form == '8-K':
                                relevant_filings.append(f'8-K ({file_date.date()})')
                    
                    # Update dataframe
                    df.at[idx, 'delisting_reason'] = primary_reason
                    df.at[idx, 'sec_filings'] = '; '.join(relevant_filings)
            
        except Exception as e:
            print(f"Error processing {row['ticker']}: {str(e)}")
        
        time.sleep(0.1)  # Respect SEC rate limits
    
    return df

# %%
# execute - and add SEC delisting reasons data to df
btech_delisted_df = add_sec_delisting_reasons(btech_delisted_df)
# Out:
# Processing PXDT (986/60)
# Processing FNCH (982/60)
# Processing GHSI (981/60)
# Processing RNLXY (983/60)
# Processing TBIO (968/60)
# Processing MPSYF (955/60)
# Processing AONC (944/60)
# Processing VAXX (945/60)
# Processing AMPE (934/60)
# Processing LIANY (914/60)
# Processing AMRX (875/60)
# Processing PYRGF (877/60)
# Processing NKGN (846/60)
# Processing COO (851/60)
# Processing AEON (844/60)
# Processing BLUAF (819/60)
# Processing ZURA (786/60)
# Processing ZYME (759/60)
# Processing CLDI (757/60)
# Processing FOXO (750/60)
# Processing FOXO (710/60)
# Processing VANI (700/60)
# Processing KLDO (684/60)
# Processing SCPX (649/60)
# Processing ANVS (617/60)
# Processing ERNA (641/60)
# Processing DNA (607/60)
# Processing SRZN (605/60)
# Processing ME (580/60)
# Processing NSPR (575/60)
# Processing ACB (577/60)
# Processing NSPR (574/60)
# Processing BIOX (578/60)
# Processing OCX (555/60)
# Processing CRMD (549/60)
# Processing VTAK (560/60)
# Processing CLOV (563/60)
# Processing AMGN (541/60)
# Processing CGC (538/60)
# Processing AZN (513/60)
# Processing CNMD (462/60)
# Processing CLPT (378/60)
# Processing RFL (398/60)
# Processing CDMO (363/60)
# Processing IRD (329/60)
# Processing SNY (281/60)
# Processing APYX (293/60)
# Processing PGEN (253/60)
# Processing NMTRQ (207/60)
# Processing QGEN (198/60)
# Processing TXMD (185/60)
# Processing LAB (144/60)
# Processing ALT (120/60)
# Processing SVRA (119/60)
# Processing PBYI (90/60)
# Processing NWBO (75/60)
# Processing ONVO (62/60)
# Processing OPK (48/60)
# Processing TRUP (32/60)
# Processing MASI (17/60)

# %%
print(len(btech_delisted_df))
display(btech_delisted_df.head())
# Out:
# 60
#           date                         company         cik form ticker   sic  \
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.  0001962845   25   PXDT  3845
# 981 2024-10-31  Finch Therapeutics Group, Inc.  0001733257   25   FNCH  2836
# 980 2024-10-11  Guardion Health Sciences, Inc.  0001642375   25   GHSI  2834
# 982 2024-10-07                   Renalytix plc  0001811115   25  RNLXY  8071
# 967 2024-09-20                Telesis Bio Inc.  0001850079   25   TBIO  3826
#
#                                      sic_description  is_biotech  \
# 985    Electromedical & Electrotherapeutic Apparatus        True
# 981  Biological Products, (No Diagnostic Substances)        True
# 980                      Pharmaceutical Preparations        True
# 982                    Services-Medical Laboratories        True
# 967                Laboratory Analytical Instruments        True
#
#                     biotech_identification_method     delisting_reason  \
# 985                                      sic_3845  Voluntary Delisting
# 981  name_match:therapeutics,therapeutic;sic_2836  Voluntary Delisting
# 980           name_match:health sciences;sic_2834  Voluntary Delisting
# 982                                      sic_8071  Voluntary Delisting
# 967                       name_match:bio;sic_3826  Voluntary Delisting
#
#                                            sec_filings
# 985                               Form 25 (2024-11-04)
# 981  Form 25 (2024-10-31); 8-K (2024-10-21); 8-K (2...
# 980  Form 25 (2024-10-11); 8-K (2024-10-03); 8-K (2...
# 982  Form 25 (2024-10-07); 8-K (2024-10-01); 8-K (2...
# 967  Form 25 (2024-09-20); 8-K (2024-09-10); 8-K (2...

# %% [markdown]
# reason filter time.

# %%
# create a breakdown grouping count of delisting reasons
print("\nDelisting Reason Breakdown:")
print(btech_delisted_df['delisting_reason'].value_counts())
# Out:
# Delisting Reason Breakdown:
# delisting_reason
# Voluntary Delisting       52
# Merger/Acquisition         5
# Unknown                    2
# Bankruptcy/Liquidation     1
# Name: count, dtype: int64

# %% [markdown]
# retrieving historical FUNDAMENTAL stock data
# - board members for xboarding
# - free or paid? , yfinance

# %% [markdown]
# retrieving historical TECHNICAL stock $ data
# - paid api? of paid

# %%
import yfinance as yf

# %%
# yfinance to pring as json all endpoints using stock PLTR
stock = yf.Ticker("PLTR")
print(stock.info)
# beautiful print
import json
print(json.dumps(stock.info, indent=4))
# Out:
# {'address1': '1200 17th Street', 'address2': 'Floor 15', 'city': 'Denver', 'state': 'CO', 'zip': '80202', 'country': 'United States', 'phone': '720 358 3679', 'website': 'https://www.palantir.com', 'industry': 'Software - Infrastructure', 'industryKey': 'software-infrastructure', 'industryDisp': 'Software - Infrastructure', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': "Palantir Technologies Inc. builds and deploys software platforms for the intelligence community to assist in counterterrorism investigations and operations in the United States, the United Kingdom, and internationally. The company provides Palantir Gotham, a software platform which enables users to identify patterns hidden deep within datasets, ranging from signals intelligence sources to reports from confidential informants, as well as facilitates the handoff between analysts and operational users, helping operators plan and execute real-world responses to threats that have been identified within the platform. It also offers Palantir Foundry, a platform that transforms the ways organizations operate by creating a central operating system for their data; and allows individual users to integrate and analyze the data they need in one place. In addition, it provides Palantir Apollo, a software that delivers software and updates across the business, as well as enables customers to deploy their software virtually in any environment; and Palantir Artificial Intelligence Platform (AIP) that provides unified access to open-source, self-hosted, and commercial large language models (LLM) that can transform structured and unstructured data into LLM-understandable objects and can turn organizations' actions and processes into tools for humans and LLM-driven agents. The company was incorporated in 2003 and is headquartered in Denver, Colorado.", 'fullTimeEmployees': 3735, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Peter Andreas Thiel', 'age': 56, 'title': 'Co-Founder & Chairman', 'yearBorn': 1967, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Dr. Alexander C. Karp', 'age': 56, 'title': 'Co-Founder, CEO & Director', 'yearBorn': 1967, 'fiscalYear': 2023, 'totalPay': 3498197, 'exercisedValue': 0, 'unexercisedValue': 204097504}, {'maxAge': 1, 'name': 'Mr. Stephen Andrew Cohen', 'age': 39, 'title': 'Co-Founder, President, Secretary & Director', 'yearBorn': 1984, 'fiscalYear': 2023, 'totalPay': 357289, 'exercisedValue': 0, 'unexercisedValue': 193482016}, {'maxAge': 1, 'name': 'Mr. David A. Glazer', 'age': 39, 'title': 'CFO & Treasurer', 'yearBorn': 1984, 'fiscalYear': 2023, 'totalPay': 474755, 'exercisedValue': 0, 'unexercisedValue': 18415654}, {'maxAge': 1, 'name': 'Mr. Shyam  Sankar', 'age': 41, 'title': 'CTO & Executive VP', 'yearBorn': 1982, 'fiscalYear': 2023, 'totalPay': 632180, 'exercisedValue': 50447856, 'unexercisedValue': 28401736}, {'maxAge': 1, 'name': 'Mr. Ryan D. Taylor', 'age': 40, 'title': 'Chief Revenue Officer & Chief Legal Officer', 'yearBorn': 1983, 'fiscalYear': 2023, 'totalPay': 464280, 'exercisedValue': 0, 'unexercisedValue': 19117024}, {'maxAge': 1, 'name': 'Mr. Joseph  Lonsdale', 'age': 40, 'title': 'Co-Founder', 'yearBorn': 1983, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Heather  Planishek', 'age': 39, 'title': 'Chief Accounting Officer', 'yearBorn': 1984, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. David B. MacNaughton', 'age': 74, 'title': 'President of Palantir Canada', 'yearBorn': 1949, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Kevin  Kawasaki', 'title': 'Head of Business Development', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 9, 'boardRisk': 10, 'compensationRisk': 10, 'shareHolderRightsRisk': 10, 'overallRisk': 10, 'governanceEpochDate': 1730419200, 'compensationAsOfEpoc ...
# {
#     "address1": "1200 17th Street",
#     "address2": "Floor 15",
#     "city": "Denver",
#     "state": "CO",
#     "zip": "80202",
#     "country": "United States",
#     "phone": "720 358 3679",
#     "website": "https://www.palantir.com",
#     "industry": "Software - Infrastructure",
#     "industryKey": "software-infrastructure",
#     "industryDisp": "Software - Infrastructure",
#     "sector": "Technology",
#     "sectorKey": "technology",
#     "sectorDisp": "Technology",
#     "longBusinessSummary": "Palantir Technologies Inc. builds and deploys software platforms for the intelligence community to assist in counterterrorism investigations and operations in the United States, the United Kingdom, and internationally. The company provides Palantir Gotham, a software platform which enables users to identify patterns hidden deep within datasets, ranging from signals intelligence sources to reports from confidential informants, as well as facilitates the handoff between analysts and operational users, helping operators plan and execute real-world responses to threats that have been identified within the platform. It also offers Palantir Foundry, a platform that transforms the ways organizations operate by creating a central operating system for their data; and allows individual users to integrate and analyze the data they need in one place. In addition, it provides Palantir Apollo, a software that delivers software and updates across the business, as well as enables customers to deploy their software virtually in any environment; and Palantir Artificial Intelligence Platform (AIP) that provides unified access to open-source, self-hosted, and commercial large language models (LLM) that can transform structured and unstructured data into LLM-understandable objects and can turn organizations' actions and processes into tools for humans and LLM-driven agents. The company was incorporated in 2003 and is headquartered in Denver, Colorado.",
#     "fullTimeEmployees": 3735,
#     "companyOfficers": [
#         {
#             "maxAge": 1,
#             "name": "Mr. Peter Andreas Thiel",
#             "age": 56,
#             "title": "Co-Founder & Chairman",
#             "yearBorn": 1967,
#             "fiscalYear": 2023,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Dr. Alexander C. Karp",
#             "age": 56,
#             "title": "Co-Founder, CEO & Director",
#             "yearBorn": 1967,
#             "fiscalYear": 2023,
#             "totalPay": 3498197,
#             "exercisedValue": 0,
#             "unexercisedValue": 204097504
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Stephen Andrew Cohen",
#             "age": 39,
#             "title": "Co-Founder, President, Secretary & Director",
#             "yearBorn": 1984,
#             "fiscalYear": 2023,
#             "totalPay": 357289,
#             "exercisedValue": 0,
#             "unexercisedValue": 193482016
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. David A. Glazer",
#             "age": 39,
#             "title": "CFO & Treasurer",
#             "yearBorn": 1984,
#             "fiscalYear": 2023,
#             "totalPay": 474755,
#             "exercisedValue": 0,
#             "unexercisedValue": 18415654
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Shyam  Sankar",
#             "age": 41,
#             "title": "CTO & Executive VP",
#             "yearBorn": 1982,
#             "fiscalYear": 2023,
#             "totalPay": 632180,
#             "exercisedValue": 50447856,
#             "unexercisedValue": 28401736
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Ryan D. Taylor",
#             "age": 40,
#             "title": "Chief Revenue Officer & Chief Legal Officer",
#             "yearBorn": 1983,
#             "fiscalYear": 2023,
#             "totalPay": 464280,
#             "exercisedValue": 0,
#             "unexercisedValue": 19117024
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Joseph  Lonsdale",
#             "age": 40,
#             "title": "Co-Founder",
#             "yearBorn": 1983,
#             "fiscalYear": 2023,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Ms. Heather  Planishek",
#             "age": 39,
#             "title": "Chief Accounting Officer",
#             "yearBorn": 1984,
#             "fiscalYear": 2023,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. David B. MacNaughton",
#             "age": 74,
#             "title": "President of Palantir Canada",
#             "yearBorn": 1949,
#             "fiscalYear": 2023,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Kevin  Kawasaki",
#             "title": "Head of Business Development",
#             "fiscalYear": 2023,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         }
#     ],
#     "auditRisk": 9,
#     "boardRisk": 10,
#     "compensationRisk": 10,
#     "shareHolderRightsRisk": 10,
#     "overallRisk": 10,
#     "governanceEpochDate": 1730419200,
#     "compensationAsOfEpochDate": 1703980800,
#     "maxAge": 86400,
#     "priceHint": 2,
#     "previousClose": 41.41,
#     "open": 47.86,
#     "dayLow": 46.86,
#     "dayHigh": 51.57,
#     "regularMarketPreviousClose": 41.41,
#     "regularMarketOpen": 47.86,
#     "regularMarketDayLow": 46.86,
#     "regularMarketDayHigh": 51.57,
#     "trailingPE": 204.52,
#     "forwardPE": 118.906975,
#     "volume": 201350475,
#     "regularMarketVolume": 201350475,
#     "averageVolume": 59491585,
#     "averageVolume10days": 40036250,
#     "averageDailyVolume10Day": 40036250,
#     "bid": 50.95,
#     "ask": 50.8,
#     "bidSize": 1200,
#     "askSize": 1800,
#     "marketCap": 109536821248,
#     "fiftyTwoWeekLow": 15.664,
#     "fiftyTwoWeekHigh": 51.57,
#     "priceToSalesTrailing12Months": 41.39185,
#     "fiftyDayAverage": 38.1734,
#     "twoHundredDayAverage": 27.59955,
#     "currency": "USD",
#     "enterpriseValue": 110827610112,
#     "profitMargins": 0.18009001,
#     "floatShares": 2068431917,
#     "sharesOutstanding": 2142320000,
#     "sharesShort": 95592527,
#     "sharesShortPriorMonth": 67110092,
#     "sharesShortPreviousMonthDate": 1726185600,
#     "dateShortInterest": 1728950400,
#     "sharesPercentSharesOut": 0.0427,
#     "heldPercentInsiders": 0.051599998,
#     "heldPercentInstitutions": 0.44943002,
#     "shortRatio": 1.26,
#     "shortPercentOfFloat": 0.048,
#     "impliedSharesOutstanding": 2239450112,
#     "bookValue": 1.999,
#     "priceToBook": 25.57779,
#     "lastFiscalYearEnd": 1703980800,
#     "nextFiscalYearEnd": 1735603200,
#     "mostRecentQuarter": 1727654400,
#     "earningsQuarterlyGrowth": 1.007,
#     "netIncomeToCommon": 476572000,
#     "trailingEps": 0.25,
#     "forwardEps": 0.43,
#     "pegRatio": 2.0,
#     "enterpriseToRevenue": 41.88,
#     "enterpriseToEbitda": 278.666,
#     "52WeekChange": 1.2026596,
#     "SandP52WeekChange": 0.30474973,
#     "exchange": "NYQ",
#     "quoteType": "EQUITY",
#     "symbol": "PLTR",
#     "underlyingSymbol": "PLTR",
#     "shortName": "Palantir Technologies Inc.",
#     "longName": "Palantir Technologies Inc.",
#     "firstTradeDateEpochUtc": 1601472600,
#     "timeZoneFullName": "America/New_York",
#     "timeZoneShortName": "EST",
#     "uuid": "0ea79370-ee21-3603-b0a1-16f5e7b345f1",
#     "messageBoardId": "finmb_43580005",
#     "gmtOffSetMilliseconds": -18000000,
#     "currentPrice": 51.13,
#     "targetHighPrice": 50.0,
#     "targetLowPrice": 9.0,
#     "targetMeanPrice": 28.85,
#     "targetMedianPrice": 29.51,
#     "recommendationMean": 3.0,
#     "recommendationKey": "hold",
#     "numberOfAnalystOpinions": 17,
#     "totalCash": 4564659200,
#     "totalCashPerShare": 2.029,
#     "ebitda": 397707008,
#     "totalDebt": 254915008,
#     "quickRatio": 5.546,
#     "currentRatio": 5.673,
#     "totalRevenue": 2646338048,
#     "debtToEquity": 5.552,
#     "revenuePerShare": 1.192,
#     "returnOnAssets": 0.045819998,
#     "returnOnEquity": 0.12409,
#     "freeCashflow": 717738496,
#     "operatingCashflow": 994710016,
#     "earningsGrowth": 1.0,
#     "revenueGrowth": 0.3,
#     "grossMargins": 0.81101996,
#     "ebitdaMargins": 0.15029,
#     "operatingMargins": 0.15594,
#     "financialCurrency": "USD",
#     "trailingPegRatio": 2.1909
# }

# %%
def get_last_trading_data(df):
    """
    Retrieve last available trading data for each delisted biotech stock
    
    Args:
        df (pd.DataFrame): DataFrame containing delisted biotech stocks info
    """
    
    def get_stock_data(row):
        try:
            # Convert delisting date to datetime if it's a string
            end_date = pd.to_datetime(row['date'])
            # Set start date to 30 days before delisting to ensure we get data
            start_date = end_date - timedelta(days=30)
            
            # Create ticker object
            ticker = yf.Ticker(row['ticker'])
            
            # Get historical data
            hist = ticker.history(
                start=start_date.strftime('%Y-%m-%d'),
                end=end_date.strftime('%Y-%m-%d')
            )
            
            if hist.empty:
                return pd.Series({
                    'last_price': None,
                    'last_volume': None,
                    'last_date': None,
                    'market_cap': None,
                    'data_retrieval_status': 'No data available'
                })
            
            # Get the last row of data
            last_data = hist.iloc[-1]
            
            return pd.Series({
                'last_price': last_data['Close'],
                'last_volume': last_data['Volume'],
                'last_date': hist.index[-1],
                'market_cap': ticker.info.get('marketCap', None),
                'data_retrieval_status': 'Success'
            })
            
        except Exception as e:
            return pd.Series({
                'last_price': None,
                'last_volume': None,
                'last_date': None,
                'market_cap': None,
                'data_retrieval_status': f'Error: {str(e)}'
            })
    
    # Create results dataframe
    results_df = pd.DataFrame()
    
    # Process each stock with a delay to avoid rate limiting
    for idx, row in df.iterrows():
        print(f"Processing {row['ticker']} ({idx + 1}/{len(df)})")
        data = get_stock_data(row)
        
        # Create a single row dataframe with all information
        stock_data = pd.DataFrame({
            'ticker': [row['ticker']],
            'company': [row['company']],
            'delisting_date': [row['date']],
            'sic_code': [row['sic']],
            'sic_description': [row['sic_description']],
            'last_price': [data['last_price']],
            'last_volume': [data['last_volume']],
            'last_trading_date': [data['last_date']],
            'market_cap': [data['market_cap']],
            'status': [data['data_retrieval_status']]
        })
        
        results_df = pd.concat([results_df, stock_data], ignore_index=True)
        
        # Add delay to avoid rate limiting
        time.sleep(1)
    
    # Clean up the data
    results_df['last_price'] = pd.to_numeric(results_df['last_price'], errors='coerce')
    results_df['last_volume'] = pd.to_numeric(results_df['last_volume'], errors='coerce')
    results_df['market_cap'] = pd.to_numeric(results_df['market_cap'], errors='coerce')
    
    # Add some basic statistics
    results_df['market_cap_millions'] = results_df['market_cap'] / 1_000_000
    
    return results_df

def analyze_delisting_data(results_df):
    """
    Analyze the retrieved delisting data
    """
    summary = {
        'total_stocks': len(results_df),
        'successful_retrievals': len(results_df[results_df['status'] == 'Success']),
        'avg_last_price': results_df['last_price'].mean(),
        'avg_market_cap_millions': results_df['market_cap_millions'].mean(),
        'median_last_volume': results_df['last_volume'].median(),
        'sic_distribution': results_df['sic_code'].value_counts().to_dict()
    }
    
    return summary

# Usage:
# biotech_delisted_df = pd.read_csv('your_data.csv')  # Your input DataFrame
# results = get_last_trading_data(biotech_delisted_df)
# analysis = analyze_delisting_data(results)

# %%
# create btdl_enriched_df 
btdl_enriched_df = get_last_trading_data(btech_delisted_df)

print(len(btech_delisted_df))
print(len(btdl_enriched_df))
btdl_enriched_df.head()
# Out:
# Processing PXDT (986/60)
# Processing FNCH (982/60)
# Processing GHSI (981/60)
# Processing RNLXY (983/60)
# Processing TBIO (968/60)
# Processing MPSYF (955/60)
# Processing AONC (944/60)
# $AONC: possibly delisted; no price data found  (1d 2024-05-01 -> 2024-05-31) (Yahoo error = "Data doesn't exist for startDate = 1714536000, endDate = 1717128000")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing VAXX (945/60)
# Processing AMPE (934/60)
# Processing LIANY (914/60)
# Processing AMRX (875/60)
# Processing PYRGF (877/60)
# Processing NKGN (846/60)
# $NKGN: possibly delisted; no price data found  (1d 2023-08-30 -> 2023-09-29) (Yahoo error = "Data doesn't exist for startDate = 1693368000, endDate = 1695960000")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing COO (851/60)
# Processing AEON (844/60)
# $AEON: possibly delisted; no price data found  (1d 2023-06-21 -> 2023-07-21) (Yahoo error = "Data doesn't exist for startDate = 1687320000, endDate = 1689912000")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing BLUAF (819/60)
# Processing ZURA (786/60)
# $ZURA: possibly delisted; no price data found  (1d 2023-02-18 -> 2023-03-20) (Yahoo error = "Data doesn't exist for startDate = 1676696400, endDate = 1679284800")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing ZYME (759/60)
# Processing CLDI (757/60)
# Processing FOXO (750/60)
# Processing FOXO (710/60)
# Processing VANI (700/60)
# Processing KLDO (684/60)
# Processing SCPX (649/60)
# Processing ANVS (617/60)
# Processing ERNA (641/60)
# Processing DNA (607/60)
# Processing SRZN (605/60)
# Processing ME (580/60)
# Processing NSPR (575/60)
# Processing ACB (577/60)
# Processing NSPR (574/60)
# Processing BIOX (578/60)
# Processing OCX (555/60)
# Processing CRMD (549/60)
# Processing VTAK (560/60)
# Processing CLOV (563/60)
# Processing AMGN (541/60)
# Processing CGC (538/60)
# Processing AZN (513/60)
# Processing CNMD (462/60)
# Processing CLPT (378/60)
# Processing RFL (398/60)
# Processing CDMO (363/60)
# Processing IRD (329/60)
# Processing SNY (281/60)
# Processing APYX (293/60)
# $APYX: possibly delisted; no price data found  (1d 2018-12-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1543640400, endDate = 1546232400")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing PGEN (253/60)
# Processing NMTRQ (207/60)
# Processing QGEN (198/60)
# Processing TXMD (185/60)
# Processing LAB (144/60)
# Processing ALT (120/60)
# $ALT: possibly delisted; no price data found  (1d 2017-04-05 -> 2017-05-05) (Yahoo error = "Data doesn't exist for startDate = 1491364800, endDate = 1493956800")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/2480574920.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing SVRA (119/60)
# $SVRA: possibly delisted; no price data found  (1d 2017-03-28 -> 2017-04-27) (Yahoo error = "Data doesn't exist for startDate = 1490673600, endDate = 1493265600")
# Processing PBYI (90/60)
# Processing NWBO (75/60)
# Processing ONVO (62/60)
# Processing OPK (48/60)
# Processing TRUP (32/60)
# Processing MASI (17/60)
# 60
# 60
#   ticker                         company delisting_date sic_code  \
# 0   PXDT   PIXIE DUST TECHNOLOGIES, INC.     2024-11-04     3845
# 1   FNCH  Finch Therapeutics Group, Inc.     2024-10-31     2836
# 2   GHSI  Guardion Health Sciences, Inc.     2024-10-11     2834
# 3  RNLXY                   Renalytix plc     2024-10-07     8071
# 4   TBIO                Telesis Bio Inc.     2024-09-20     3826
#
#                                    sic_description  last_price  last_volume  \
# 0    Electromedical & Electrotherapeutic Apparatus       0.860     104000.0
# 1  Biological Products, (No Diagnostic Substances)      11.900        400.0
# 2                      Pharmaceutical Preparations       3.260      36861.0
# 3                    Services-Medical Laboratories       0.196     284300.0
# 4                Laboratory Analytical Instruments       2.930   53735400.0
#
#           last_trading_date  market_cap   status  market_cap_millions
# 0 2024-11-01 00:00:00-04:00  12311615.0  Success            12.311615
# 1 2024-10-30 00:00:00-04:00  19477868.0  Success            19.477868
# 2 2024-10-10 00:00:00-04:00   4346871.0  Success             4.346871
# 3 2024-10-04 00:00:00-04:00  18982950.0  Success            18.982950
# 4 2024-09-19 00:00:00-04:00   2233917.0  Success             2.233917

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta
import time
import json

def get_stock_fundamentals(df):
    """
    Retrieve fundamental data including company officers and sector information
    """
    
    def get_officer_details(officers):
        """Helper function to format officer information"""
        if not officers:
            return None
        
        officer_list = []
        for officer in officers:
            officer_info = {
                'name': officer.get('name'),
                'title': officer.get('title'),
                'age': officer.get('age'),
                'yearBorn': officer.get('yearBorn'),
                'totalPay': officer.get('totalPay')
            }
            officer_list.append(officer_info)
        
        return json.dumps(officer_list)  # Store as JSON string

    def get_fundamentals(row):
        try:
            # Create ticker object
            ticker = yf.Ticker(row['ticker'])
            
            # Get last price data
            end_date = pd.to_datetime(row['date'])
            start_date = end_date - timedelta(days=30)
            
            hist = ticker.history(
                start=start_date.strftime('%Y-%m-%d'),
                end=end_date.strftime('%Y-%m-%d')
            )
            
            last_price = hist['Close'].iloc[-1] if not hist.empty else None
            
            # Get fundamental data
            info = ticker.info
            
            # Basic company information
            results = {
                'last_price': last_price,
                'sector': info.get('sector'),
                'industry': info.get('industry'),
                'company_officers': get_officer_details(info.get('companyOfficers')),
                
                # Financial metrics
                'market_cap': info.get('marketCap'),
                'enterprise_value': info.get('enterpriseValue'),
                'total_cash': info.get('totalCash'),
                'total_debt': info.get('totalDebt'),
                'total_revenue': info.get('totalRevenue'),
                'gross_profits': info.get('grossProfits'),
                'free_cashflow': info.get('freeCashflow'),
                'research_development': info.get('researchAndDevelopment'),
                
                # Additional metrics
                'number_of_employees': info.get('fullTimeEmployees'),
                'shares_outstanding': info.get('sharesOutstanding'),
                'float_shares': info.get('floatShares'),
                'beta': info.get('beta'),
                
                # Status
                'data_retrieval_status': 'Success'
            }
            
            return pd.Series(results)
            
        except Exception as e:
            # Create empty results
            results = {
                'last_price': None,
                'sector': None,
                'industry': None,
                'company_officers': None,
                'market_cap': None,
                'enterprise_value': None,
                'total_cash': None,
                'total_debt': None,
                'total_revenue': None,
                'gross_profits': None,
                'free_cashflow': None,
                'research_development': None,
                'number_of_employees': None,
                'shares_outstanding': None,
                'float_shares': None,
                'beta': None,
                'data_retrieval_status': f'Error: {str(e)}'
            }
            
            return pd.Series(results)
    
    # Create results dataframe
    results_df = pd.DataFrame()
    
    # Process each stock
    total_stocks = len(df)
    for idx, row in df.iterrows():
        print(f"Processing {row['ticker']} ({idx + 1}/{total_stocks})")
        
        # Get fundamental data
        fund_data = get_fundamentals(row)
        
        # Create a single row dataframe
        stock_data = pd.DataFrame({
            'ticker': [row['ticker']],
            'company': [row['company']],
            'delisting_date': [row['date']],
            'sic_code': [row['sic']],
            'sic_description': [row['sic_description']],
            **{k: [v] for k, v in fund_data.items()}
        })
        
        results_df = pd.concat([results_df, stock_data], ignore_index=True)
        
        # Add delay to avoid rate limiting
        time.sleep(1.5)
    
    # Convert numeric columns
    numeric_columns = [
        'last_price', 'market_cap', 'enterprise_value', 'total_cash', 
        'total_debt', 'total_revenue', 'gross_profits', 'free_cashflow',
        'research_development', 'number_of_employees', 'shares_outstanding',
        'float_shares', 'beta'
    ]
    
    for col in numeric_columns:
        results_df[col] = pd.to_numeric(results_df[col], errors='coerce')
    
    # Add derived metrics
    results_df['net_cash'] = results_df['total_cash'] - results_df['total_debt']
    results_df['cash_to_debt_ratio'] = results_df['total_cash'] / results_df['total_debt']
    results_df['rd_to_revenue_ratio'] = results_df['research_development'] / results_df['total_revenue']
    
    return results_df

def analyze_officers(results_df):
    """
    Analyze the company officers data
    """
    officer_analysis = []
    
    for _, row in results_df.iterrows():
        if row['company_officers']:
            try:
                officers = json.loads(row['company_officers'])
                officer_analysis.append({
                    'ticker': row['ticker'],
                    'company': row['company'],
                    'number_of_officers': len(officers),
                    'officers': officers
                })
            except:
                continue
    
    return pd.DataFrame(officer_analysis)

def summarize_results(results_df):
    """
    Create a summary of the results
    """
    summary = {
        'total_stocks': len(results_df),
        'successful_retrievals': len(results_df[results_df['data_retrieval_status'] == 'Success']),
        'sectors_distribution': results_df['sector'].value_counts().to_dict(),
        'avg_metrics': {
            'market_cap': results_df['market_cap'].mean(),
            'total_cash': results_df['total_cash'].mean(),
            'total_debt': results_df['total_debt'].mean(),
            'rd_expense': results_df['research_development'].mean()
        }
    }
    
    # Get officer statistics
    officer_df = analyze_officers(results_df)
    if not officer_df.empty:
        summary['officer_stats'] = {
            'avg_officers_per_company': officer_df['number_of_officers'].mean(),
            'max_officers': officer_df['number_of_officers'].max(),
            'companies_with_officer_data': len(officer_df)
        }
    
    return summary

# Example usage:
# results = get_stock_fundamentals(biotech_delisted_df)
# summary = summarize_results(results)
# officer_details = analyze_officers(results)

# %%
# Get the full data
bt_officers_df = get_stock_fundamentals(btech_delisted_df)

print(len(btech_delisted_df))
display(bt_officers_df.head())

# # Get officer-specific analysis
# officer_analysis = analyze_officers(results)

# # Get overall summary
# summary = summarize_results(results)

# # View officer details for a specific company
# company_officers = results.loc[results['ticker'] == 'SPECIFIC_TICKER', 'company_officers'].iloc[0]
# if company_officers:
#     print(json.loads(company_officers))
# Out:
# Processing PXDT (986/60)
# Processing FNCH (982/60)
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing GHSI (981/60)
# Processing RNLXY (983/60)
# Processing TBIO (968/60)
# Processing MPSYF (955/60)
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing AONC (944/60)
# $AONC: possibly delisted; no price data found  (1d 2024-05-01 -> 2024-05-31) (Yahoo error = "Data doesn't exist for startDate = 1714536000, endDate = 1717128000")
# Processing VAXX (945/60)
# Processing AMPE (934/60)
# Processing LIANY (914/60)
# Processing AMRX (875/60)
# Processing PYRGF (877/60)
# Processing NKGN (846/60)
# $NKGN: possibly delisted; no price data found  (1d 2023-08-30 -> 2023-09-29) (Yahoo error = "Data doesn't exist for startDate = 1693368000, endDate = 1695960000")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing COO (851/60)
# Processing AEON (844/60)
# $AEON: possibly delisted; no price data found  (1d 2023-06-21 -> 2023-07-21) (Yahoo error = "Data doesn't exist for startDate = 1687320000, endDate = 1689912000")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing BLUAF (819/60)
# Processing ZURA (786/60)
# $ZURA: possibly delisted; no price data found  (1d 2023-02-18 -> 2023-03-20) (Yahoo error = "Data doesn't exist for startDate = 1676696400, endDate = 1679284800")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing ZYME (759/60)
# Processing CLDI (757/60)
# Processing FOXO (750/60)
# Processing FOXO (710/60)
# Processing VANI (700/60)
# Processing KLDO (684/60)
# Processing SCPX (649/60)
# Processing ANVS (617/60)
# Processing ERNA (641/60)
# Processing DNA (607/60)
# Processing SRZN (605/60)
# Processing ME (580/60)
# Processing NSPR (575/60)
# Processing ACB (577/60)
# Processing NSPR (574/60)
# Processing BIOX (578/60)
# Processing OCX (555/60)
# Processing CRMD (549/60)
# Processing VTAK (560/60)
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing CLOV (563/60)
# Processing AMGN (541/60)
# Processing CGC (538/60)
# Processing AZN (513/60)
# Processing CNMD (462/60)
# Processing CLPT (378/60)
# Processing RFL (398/60)
# Processing CDMO (363/60)
# Processing IRD (329/60)
# Processing SNY (281/60)
# Processing APYX (293/60)
# $APYX: possibly delisted; no price data found  (1d 2018-12-01 -> 2018-12-31) (Yahoo error = "Data doesn't exist for startDate = 1543640400, endDate = 1546232400")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing PGEN (253/60)
# Processing NMTRQ (207/60)
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing QGEN (198/60)
# Processing TXMD (185/60)
# Processing LAB (144/60)
# Processing ALT (120/60)
# $ALT: possibly delisted; no price data found  (1d 2017-04-05 -> 2017-05-05) (Yahoo error = "Data doesn't exist for startDate = 1491364800, endDate = 1493956800")
# /var/folders/8w/4mj_4m4d0rs1q22bl9g77hhw0000gn/T/ipykernel_96350/4102864954.py:123: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, stock_data], ignore_index=True)
# Processing SVRA (119/60)
# $SVRA: possibly delisted; no price data found  (1d 2017-03-28 -> 2017-04-27) (Yahoo error = "Data doesn't exist for startDate = 1490673600, endDate = 1493265600")
# Processing PBYI (90/60)
# Processing NWBO (75/60)
# Processing ONVO (62/60)
# Processing OPK (48/60)
# Processing TRUP (32/60)
# Processing MASI (17/60)
# 60
#   ticker                         company delisting_date sic_code  \
# 0   PXDT   PIXIE DUST TECHNOLOGIES, INC.     2024-11-04     3845
# 1   FNCH  Finch Therapeutics Group, Inc.     2024-10-31     2836
# 2   GHSI  Guardion Health Sciences, Inc.     2024-10-11     2834
# 3  RNLXY                   Renalytix plc     2024-10-07     8071
# 4   TBIO                Telesis Bio Inc.     2024-09-20     3826
#
#                                    sic_description  last_price      sector  \
# 0    Electromedical & Electrotherapeutic Apparatus       0.860  Technology
# 1  Biological Products, (No Diagnostic Substances)      11.900  Healthcare
# 2                      Pharmaceutical Preparations       3.260  Healthcare
# 3                    Services-Medical Laboratories       0.196  Healthcare
# 4                Laboratory Analytical Instruments       2.930  Healthcare
#
#                                    industry  \
# 0                      Consumer Electronics
# 1                             Biotechnology
# 2  Drug Manufacturers - Specialty & Generic
# 3               Health Information Services
# 4                           Medical Devices
#
#                                     company_officers  market_cap  ...  \
# 0  [{"name": "Dr. Yoichi  Ochiai", "title": "Co-F...  12311615.0  ...
# 1  [{"name": "Mr. Matthew P. Blischak J.D.", "tit...  19477868.0  ...
# 2  [{"name": "Mr. Robert Neal Weingarten", "title...   4346871.0  ...
# 3  [{"name": "Mr. James R. McCullough M.B.A.", "t...  18982950.0  ...
# 4  [{"name": "Mr. Eric  Esser", "title": "Preside...   2233917.0  ...
#
#    free_cashflow  research_development  number_of_employees  \
# 0  -1.338085e+09                   NaN                 76.0
# 1  -1.596362e+07                   NaN                  1.0
# 2   1.377253e+06                   NaN                  9.0
# 3  -1.947312e+07                   NaN                  NaN
# 4  -9.338625e+06                   NaN                101.0
#
#    shares_outstanding  float_shares   beta  data_retrieval_status    net_cash  \
# 0          14869100.0     5869118.0    NaN                Success  60549888.0
# 1           1605760.0      896016.0  1.329                Success -12954000.0
# 2           1349960.0     1160582.0  0.708                Success         NaN
# 3          94966600.0   139219802.0  2.103                Success  -3855000.0
# 4           1772950.0      612110.0  1.758                Success -25339000.0
#
#    cash_to_debt_ratio  rd_to_revenue_ratio
# 0            1.039135                  NaN
# 1            0.553141                  NaN
# 2                 NaN                  NaN
# 3            0.548330                  NaN
# 4            0.287289                  NaN
#
# [5 rows x 25 columns]

# %%
print(len(btech_delisted_df))
print(len(bt_officers_df))
# Out:
# 60
# 60

# %%
print(len(btech_delisted_df) == len(bt_officers_df))
print(len(btech_delisted_df), len(bt_officers_df))

print('\nDATA MINING OUTPUT\n')

print('btech OFFICERS')
display(bt_officers_df.head())
display(bt_officers_df.columns)
print('btech SICK data mining output')
display(btech_delisted_df.head())
display(btech_delisted_df.columns)
# Out:
# True
# 60 60
#
# DATA MINING OUTPUT
#
# btech OFFICERS
#   ticker                         company delisting_date sic_code  \
# 0   PXDT   PIXIE DUST TECHNOLOGIES, INC.     2024-11-04     3845
# 1   FNCH  Finch Therapeutics Group, Inc.     2024-10-31     2836
# 2   GHSI  Guardion Health Sciences, Inc.     2024-10-11     2834
# 3  RNLXY                   Renalytix plc     2024-10-07     8071
# 4   TBIO                Telesis Bio Inc.     2024-09-20     3826
#
#                                    sic_description  last_price      sector  \
# 0    Electromedical & Electrotherapeutic Apparatus       0.860  Technology
# 1  Biological Products, (No Diagnostic Substances)      11.900  Healthcare
# 2                      Pharmaceutical Preparations       3.260  Healthcare
# 3                    Services-Medical Laboratories       0.196  Healthcare
# 4                Laboratory Analytical Instruments       2.930  Healthcare
#
#                                    industry  \
# 0                      Consumer Electronics
# 1                             Biotechnology
# 2  Drug Manufacturers - Specialty & Generic
# 3               Health Information Services
# 4                           Medical Devices
#
#                                     company_officers  market_cap  ...  \
# 0  [{"name": "Dr. Yoichi  Ochiai", "title": "Co-F...  12311615.0  ...
# 1  [{"name": "Mr. Matthew P. Blischak J.D.", "tit...  19477868.0  ...
# 2  [{"name": "Mr. Robert Neal Weingarten", "title...   4346871.0  ...
# 3  [{"name": "Mr. James R. McCullough M.B.A.", "t...  18982950.0  ...
# 4  [{"name": "Mr. Eric  Esser", "title": "Preside...   2233917.0  ...
#
#    free_cashflow  research_development  number_of_employees  \
# 0  -1.338085e+09                   NaN                 76.0
# 1  -1.596362e+07                   NaN                  1.0
# 2   1.377253e+06                   NaN                  9.0
# 3  -1.947312e+07                   NaN                  NaN
# 4  -9.338625e+06                   NaN                101.0
#
#    shares_outstanding  float_shares   beta  data_retrieval_status    net_cash  \
# 0          14869100.0     5869118.0    NaN                Success  60549888.0
# 1           1605760.0      896016.0  1.329                Success -12954000.0
# 2           1349960.0     1160582.0  0.708                Success         NaN
# 3          94966600.0   139219802.0  2.103                Success  -3855000.0
# 4           1772950.0      612110.0  1.758                Success -25339000.0
#
#    cash_to_debt_ratio  rd_to_revenue_ratio
# 0            1.039135                  NaN
# 1            0.553141                  NaN
# 2                 NaN                  NaN
# 3            0.548330                  NaN
# 4            0.287289                  NaN
#
# [5 rows x 25 columns]
# Index(['ticker', 'company', 'delisting_date', 'sic_code', 'sic_description',
#        'last_price', 'sector', 'industry', 'company_officers', 'market_cap',
#        'enterprise_value', 'total_cash', 'total_debt', 'total_revenue',
#        'gross_profits', 'free_cashflow', 'research_development',
#        'number_of_employees', 'shares_outstanding', 'float_shares', 'beta',
#        'data_retrieval_status', 'net_cash', 'cash_to_debt_ratio',
#        'rd_to_revenue_ratio'],
#       dtype='object')
# btech SICK data mining output
#           date                         company         cik form ticker   sic  \
# 985 2024-11-04   PIXIE DUST TECHNOLOGIES, INC.  0001962845   25   PXDT  3845
# 981 2024-10-31  Finch Therapeutics Group, Inc.  0001733257   25   FNCH  2836
# 980 2024-10-11  Guardion Health Sciences, Inc.  0001642375   25   GHSI  2834
# 982 2024-10-07                   Renalytix plc  0001811115   25  RNLXY  8071
# 967 2024-09-20                Telesis Bio Inc.  0001850079   25   TBIO  3826
#
#                                      sic_description  is_biotech  \
# 985    Electromedical & Electrotherapeutic Apparatus        True
# 981  Biological Products, (No Diagnostic Substances)        True
# 980                      Pharmaceutical Preparations        True
# 982                    Services-Medical Laboratories        True
# 967                Laboratory Analytical Instruments        True
#
#                     biotech_identification_method     delisting_reason  \
# 985                                      sic_3845  Voluntary Delisting
# 981  name_match:therapeutics,therapeutic;sic_2836  Voluntary Delisting
# 980           name_match:health sciences;sic_2834  Voluntary Delisting
# 982                                      sic_8071  Voluntary Delisting
# 967                       name_match:bio;sic_3826  Voluntary Delisting
#
#                                            sec_filings
# 985                               Form 25 (2024-11-04)
# 981  Form 25 (2024-10-31); 8-K (2024-10-21); 8-K (2...
# 980  Form 25 (2024-10-11); 8-K (2024-10-03); 8-K (2...
# 982  Form 25 (2024-10-07); 8-K (2024-10-01); 8-K (2...
# 967  Form 25 (2024-09-20); 8-K (2024-09-10); 8-K (2...
# Index(['date', 'company', 'cik', 'form', 'ticker', 'sic', 'sic_description',
#        'is_biotech', 'biotech_identification_method', 'delisting_reason',
#        'sec_filings'],
#       dtype='object')

# %% [markdown]
# figure out in what way to effectively to combine this data

# %% [markdown]
# make your next dataframe historical price and chart, technicals

# %%
# Assuming bt_officers_df and btech_delist_df are already defined

# Select the required columns from bt_officers_df
bt_officers_selected = bt_officers_df[['ticker', 'company', 'delisting_date', 'sic_code', 'sic_description',
                                       'last_price', 'sector', 'industry', 'company_officers']]

# Select the required columns from btech_delist_df
btech_delisted_selected = btech_delisted_df[['ticker', 'is_biotech', 'biotech_identification_method', 'delisting_reason']]

# Merge the two DataFrames on the 'ticker' column
bt_dialed_df = pd.merge(bt_officers_selected, btech_delisted_selected, on='ticker', how='inner')

print(len(bt_dialed_df))
# Out:
#    ticker                         company delisting_date sic_code  \
# 0    PXDT   PIXIE DUST TECHNOLOGIES, INC.     2024-11-04     3845
# 1    FNCH  Finch Therapeutics Group, Inc.     2024-10-31     2836
# 2    GHSI  Guardion Health Sciences, Inc.     2024-10-11     2834
# 3   RNLXY                   Renalytix plc     2024-10-07     8071
# 4    TBIO                Telesis Bio Inc.     2024-09-20     3826
# ..    ...                             ...            ...      ...
# 59   NWBO   NORTHWEST BIOTHERAPEUTICS INC     2016-12-19     2834
# 60   ONVO         ORGANOVO HOLDINGS, INC.     2016-08-05     2836
# 61    OPK               Opko Health, Inc.     2016-06-23     2834
# 62   TRUP                  TRUPANION INC.     2016-06-16     6324
# 63   MASI                     MASIMO CORP     2016-02-17     3845
#
#                                     sic_description  last_price  \
# 0     Electromedical & Electrotherapeutic Apparatus    0.860000
# 1   Biological Products, (No Diagnostic Substances)   11.900000
# 2                       Pharmaceutical Preparations    3.260000
# 3                     Services-Medical Laboratories    0.196000
# 4                 Laboratory Analytical Instruments    2.930000
# ..                                              ...         ...
# 59                      Pharmaceutical Preparations    0.570000
# 60  Biological Products, (No Diagnostic Substances)   86.599998
# 61                      Pharmaceutical Preparations    9.360000
# 62                 Hospital & Medical Service Plans   13.000000
# 63    Electromedical & Electrotherapeutic Apparatus   36.470001
#
#                 sector                                  industry  \
# 0           Technology                      Consumer Electronics
# 1           Healthcare                             Biotechnology
# 2           Healthcare  Drug Manufacturers - Specialty & Generic
# 3           Healthcare               Health Information Services
# 4           Healthcare                           Medical Devices
# ..                 ...                                       ...
# 59          Healthcare                             Biotechnology
# 60          Healthcare                             Biotechnology
# 61          Healthcare                    Diagnostics & Research
# 62  Financial Services                     Insurance - Specialty
# 63          Healthcare                           Medical Devices
#
#                                      company_officers  is_biotech  \
# 0   [{"name": "Dr. Yoichi  Ochiai", "title": "Co-F...        True
# 1   [{"name": "Mr. Matthew P. Blischak J.D.", "tit...        True
# 2   [{"name": "Mr. Robert Neal Weingarten", "title...        True
# 3   [{"name": "Mr. James R. McCullough M.B.A.", "t...        True
# 4   [{"name": "Mr. Eric  Esser", "title": "Preside...        True
# ..                                                ...         ...
# 59  [{"name": "Ms. Linda F. Powers J.D.", "title":...        True
# 60  [{"name": "Mr. Keith E. Murphy", "title": "Exe...        True
# 61  [{"name": "Dr. Phillip  Frost Ph.D.", "title":...        True
# 62  [{"name": "Mr. Darryl Graham Andrew Rawlings",...        True
# 63  [{"name": "Mr. Micah  Young", "title": "Execut...        True
#
#                        biotech_identification_method     delisting_reason
# 0                                           sic_3845  Voluntary Delisting
# 1       name_match:therapeutics,therapeutic;sic_2836  Voluntary Delisting
# 2                name_match:health sciences;sic_2834  Voluntary Delisting
# 3                                           sic_8071  Voluntary Delisting
# 4                            name_match:bio;sic_3826  Voluntary Delisting
# ..                                               ...                  ...
# 59  name_match:therapeutics,bio,therapeutic;sic_2834  Voluntary Delisting
# 60                                          sic_2836  Voluntary Delisting
# 61                                          sic_2834  Voluntary Delisting
# 62                                          sic_6324              Unknown
# 63                                          sic_3845  Voluntary Delisting
#
# [64 rows x 12 columns]

# %% [markdown]
# # GET historical data for TARGETS

# %%
print(len(alt_ev_screen_df))
display(alt_ev_screen_df.head())
print(alt_ev_screen_df.columns)
# Out:
# 52
#   Ticker  Last Price  YTD Returns  Cover Days        SI NT Uptrend  \
# 0   PRE       4.7700    -0.192893    1.056601  0.003922  -0.010658
# 1  ANTX       1.1000    -0.946315    1.365465  0.006300  -0.007799
# 2  BOLT       0.6596    -0.411039    1.523604  0.003992  -0.000992
# 3  ALGS       8.7500    -0.472892    1.754932  0.033707  -0.262578
# 4   KZR       0.7651    -0.192421    0.671468  0.017282   0.191504
#
#    Intermediate Term Uptrend    20 DMA    50 DMA   100 DMA  ...  Total Debt  \
# 0                  -0.074336  0.035944  0.024903 -0.089601  ...    2.369388
# 1                  -0.729220  0.041667  0.033543 -0.334483  ...    0.000000
# 2                  -0.282287  0.019971  0.018959 -0.044480  ...   20.219000
# 3                  -0.327272  0.128086 -0.168124 -0.230097  ...   11.138000
# 4                  -0.093192 -0.061710  0.117976  0.164678  ...   18.933000
#
#       Current     2Q24 EV     3Q24 EV Cash on Hand Net Loss (Qs)  20 DMA.1  \
# 0 -124.177628 -112.677628 -101.177628   183.873483       -11.500  4.604495
# 1  -71.713326  -60.213326  -48.713326   104.540000       -11.500     1.056
# 2  -56.729132  -43.277132  -29.825132   102.189000       -13.452  0.646685
# 3  -55.432097  -46.087097  -36.742097    94.536000        -9.345    7.7565
# 4  -89.425605  -66.425605  -43.425605   164.182000       -23.000   0.81542
#
#     50 DMA.1  100 DMA.1  200 DMA.1
# 0   4.654098   5.239461   5.027851
# 1   1.064300   1.652850   3.930500
# 2   0.647327   0.690304   0.901930
# 3  10.518400  11.365075  15.635444
# 4   0.684362   0.656920   0.754693
#
# [5 rows x 27 columns]
# Index(['Ticker', 'Last Price', 'YTD Returns', 'Cover Days', 'SI', 'NT Uptrend',
#        'Intermediate Term Uptrend', '20 DMA', '50 DMA', '100 DMA', '200 DMA',
#        '2Q24', '3Q24', '4Q24', 'ADV $M', 'Cash Runway (Qs)', 'Market Cap',
#        'Total Debt', 'Current', '2Q24 EV', '3Q24 EV', 'Cash on Hand',
#        'Net Loss (Qs)', '20 DMA.1', '50 DMA.1', '100 DMA.1', '200 DMA.1'],
#       dtype='object')

# %%
# list of stocks from Alternative EV Screen
alt_ev_screen_ticker_list = alt_ev_screen_df['Ticker'].tolist()
# strop any leading or trailing white spaces
alt_ev_screen_ticker_list = [ticker.strip() for ticker in alt_ev_screen_ticker_list if isinstance(ticker, str)]


print(len(alt_ev_screen_ticker_list))
print(alt_ev_screen_ticker_list[:5])
# Out:
# 47
# ['PRE', 'ANTX', 'BOLT', 'ALGS', 'KZR']

# %%
# get historical data for TARGET biotech stocks
def get_historical_data(tickers, start_date, end_date):
    data = {}
    for ticker in tickers:
        try:
            stock = yf.Ticker(ticker)
            data[ticker] = stock.history(start=start_date, end=end_date)            
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")
    
    return data

# %%
print(alt_ev_screen_ticker_list[:5])
start_date = '2024-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')
# Out:
# ['PRE', 'ANTX', 'BOLT', 'ALGS', 'KZR']

# %%
# targets historical price df
tgts_hp_df = get_historical_data(alt_ev_screen_ticker_list, start_date, end_date)


print(len(alt_ev_screen_ticker_list))
print(len(tgts_hp_df))
# Out:
# 47
# 47

# %% [markdown]
# larger data set stored in dictionary format

# %%
print(len(tgts_hp_df))
print(tgts_hp_df)

# # save as a pandas dataframe
# tgts_hp_df = pd.concat(tgts_hp_df)
# print(len(tgts_hp_df))
# display(tgts_hp_df.head())
# Out:
# 47
# {'PRE':                             Open   High    Low  Close  Volume  Dividends  \
# Date
# 2024-01-02 00:00:00-05:00  5.670  5.800  5.220  5.620    3800        0.0
# 2024-01-03 00:00:00-05:00  5.680  5.770  5.680  5.725    1400        0.0
# 2024-01-04 00:00:00-05:00  5.710  5.820  5.540  5.570    6900        0.0
# 2024-01-05 00:00:00-05:00  5.393  5.590  5.310  5.310    3000        0.0
# 2024-01-08 00:00:00-05:00  5.212  5.451  5.212  5.220  130800        0.0
# ...                          ...    ...    ...    ...     ...        ...
# 2024-10-29 00:00:00-04:00  4.770  4.770  4.770  4.770       0        0.0
# 2024-10-30 00:00:00-04:00  4.564  4.770  4.564  4.640    9700        0.0
# 2024-10-31 00:00:00-04:00  4.600  4.797  4.550  4.640    3900        0.0
# 2024-11-01 00:00:00-04:00  4.640  4.640  4.477  4.620    1900        0.0
# 2024-11-04 00:00:00-05:00  4.525  4.575  4.290  4.360    9500        0.0
#
#                            Stock Splits
# Date
# 2024-01-02 00:00:00-05:00           0.0
# 2024-01-03 00:00:00-05:00           0.0
# 2024-01-04 00:00:00-05:00           0.0
# 2024-01-05 00:00:00-05:00           0.0
# 2024-01-08 00:00:00-05:00           0.0
# ...                                 ...
# 2024-10-29 00:00:00-04:00           0.0
# 2024-10-30 00:00:00-04:00           0.0
# 2024-10-31 00:00:00-04:00           0.0
# 2024-11-01 00:00:00-04:00           0.0
# 2024-11-04 00:00:00-05:00           0.0
#
# [213 rows x 7 columns], '
# ...                          ...     ...     ...    ...      ...        ...
# 2024-10-29 00:00:00-04:00   5.95   6.180   5.880   5.99  1275600        0.0
# 2024-10-30 00:00:00-04:00   5.92   6.140   5.675   5.79  1242200        0.0
# 2024-10-31 00:00:00-04:00   5.77   5.830   5.620   5.73  1085200        0.0
# 2024-11-01 00:00:00-04:00   5.73   5.955   5.650   5.93  1158300        0.0
# 2024-11-04 00:00:00-05:00   5.95   6.165   5.620   6.05   920700        0.0
#
#                            Stock Splits
# Date
# 2024-01-02 00:00:00-05:00           0.0
# 2024-01-03 00:00:00-05:00           0.0
# 2024-01-04 00:00:00-05:00           0.0
# 2024-01-05 00:00:00-05:00           0.0
# 2024-01-08 00:00:00-05:00           0.0
# ...                                 ...
# 2024-10-29 00:00:00-04:00           0.0
# 2024-10-30 00:00:00-04:00           0.0
# 2024-10-31 00:00:00-04:00           0.0
# 2024-11-01 00:00:00-04:00           0.0
# 2024-11-04 00:00:00-05:00           0.0
#
# [213 rows x 7 columns]}

# %% [markdown]
# # GET historical data for DELISTED
# #### CHALLENGE

# %%
print(len(bt_dialed_df))
display(bt_dialed_df.head())
print(bt_dialed_df.columns)
# Out:
# 64
#   ticker                         company delisting_date sic_code  \
# 0   PXDT   PIXIE DUST TECHNOLOGIES, INC.     2024-11-04     3845
# 1   FNCH  Finch Therapeutics Group, Inc.     2024-10-31     2836
# 2   GHSI  Guardion Health Sciences, Inc.     2024-10-11     2834
# 3  RNLXY                   Renalytix plc     2024-10-07     8071
# 4   TBIO                Telesis Bio Inc.     2024-09-20     3826
#
#                                    sic_description  last_price      sector  \
# 0    Electromedical & Electrotherapeutic Apparatus       0.860  Technology
# 1  Biological Products, (No Diagnostic Substances)      11.900  Healthcare
# 2                      Pharmaceutical Preparations       3.260  Healthcare
# 3                    Services-Medical Laboratories       0.196  Healthcare
# 4                Laboratory Analytical Instruments       2.930  Healthcare
#
#                                    industry  \
# 0                      Consumer Electronics
# 1                             Biotechnology
# 2  Drug Manufacturers - Specialty & Generic
# 3               Health Information Services
# 4                           Medical Devices
#
#                                     company_officers  is_biotech  \
# 0  [{"name": "Dr. Yoichi  Ochiai", "title": "Co-F...        True
# 1  [{"name": "Mr. Matthew P. Blischak J.D.", "tit...        True
# 2  [{"name": "Mr. Robert Neal Weingarten", "title...        True
# 3  [{"name": "Mr. James R. McCullough M.B.A.", "t...        True
# 4  [{"name": "Mr. Eric  Esser", "title": "Preside...        True
#
#                   biotech_identification_method     delisting_reason
# 0                                      sic_3845  Voluntary Delisting
# 1  name_match:therapeutics,therapeutic;sic_2836  Voluntary Delisting
# 2           name_match:health sciences;sic_2834  Voluntary Delisting
# 3                                      sic_8071  Voluntary Delisting
# 4                       name_match:bio;sic_3826  Voluntary Delisting
# Index(['ticker', 'company', 'delisting_date', 'sic_code', 'sic_description',
#        'last_price', 'sector', 'industry', 'company_officers', 'is_biotech',
#        'biotech_identification_method', 'delisting_reason'],
#       dtype='object')

# %% [markdown]
# # TradingView Chart Experiments
